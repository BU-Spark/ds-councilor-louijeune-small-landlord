# %% [markdown]
# # Import Setting

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Datasets

# %% [markdown]
# ### 1.Load Boston Assessor Dataset

# %%
df_boston = pd.read_csv('data/BostonAssessorsDataCleaned.csv', low_memory=False)
df_boston[:3]
# Out:
#    Unnamed: 0    PROP_ID            LOC_ID  BLDG_VAL  LAND_VAL  OTHER_VAL  \
# 0           1  100213000  F_783144_2964233         0         0          0
# 1           5  100218000  F_783205_2964264    437000    291800          0
# 2           6  100219000  F_783236_2964275    472900    267300          0
#
#    TOTAL_VAL    FY  LOT_SIZE     LS_DATE  ...  AssessedYear   acreage  \
# 0          0  2020       0.0  19920928.0  ...        2020.0  0.228752
# 1     728800  2020       0.0  19990202.0  ...        2020.0  0.077937
# 2     740200  2020       0.0  20161109.0  ...        2020.0  0.064641
#
#   StandardizedUseCodes StandardizedUseDesc  \
# 0                  102         Condominium
# 1                  105        Three-family
# 2                  105        Three-family
#
#                               NonResidentialUses  \
# 0  Tax-exempt, public, charitable, institutional
# 1                                            NaN
# 2                                            NaN
#
#                                       UseDesc residentialunits    unitsource  \
# 0  Residential Condominium, Other, Open Space              4.0  MHP estimate
# 1                    Three-Family Residential              4.0  MHP estimate
# 2                    Three-Family Residential              4.0  MHP estimate
#
#          DUA Developable
# 0  17.486216         NaN
# 1  51.323242         NaN
# 2  61.879834         NaN
#
# [3 rows x 50 columns]

# %% [markdown]
# ### 2.Load Income Restricted Dataset

# %%
df_income = pd.read_csv('data/income-restricted-inventory-2021.csv')
df_income[:3]
# Out:
#                 Project Name Neighborhood  Zip Code  TtlProjUnits  RentUnits  \
# 0  Abbot Street/ Shawmut Ave      Roxbury    2119.0            16         16
# 1            Academy Homes I      Roxbury    2119.0           202        202
# 2           Academy Homes II      Roxbury    2119.0           236        236
#
#    OwnUnits  TtlMarket  MarketRent  MarketOwn  Total Income-Restricted  \
# 0         0        0.0         0.0        0.0                       16
# 1         0       52.0        52.0        0.0                      150
# 2         0        0.0         0.0        0.0                      236
#
#    Income-Restricted Rental  Income-Restricted Ownership  Tenure  \
# 0                        16                          0.0  Rental
# 1                       150                          0.0  Rental
# 2                       236                          0.0  Rental
#
#   Public/ Private Includes Senior Units? Section 8
# 0         Private                    NaN       NaN
# 1         Private                    NaN       NaN
# 2         Private                    NaN         Y

# %%
# fill na with 0 in Zip Code column in income restircted data frame
df_income["Zip Code"] = df_income["Zip Code"].fillna(0)

# %% [markdown]
# # Clean Data

# %% [markdown]
# ### 1. Get Address Info For Income Restricted Dataset

# %%
import requests
import os

url = "https://maps.googleapis.com/maps/api/place/findplacefromtext/json"
# API_KEY = 'AIzaSyCn2EnyZryAoJoe72jb8CddMDtsrhs3_mU'
API_KEY = 'AIzaSyBaaG87dMzXfKu05Zxyt3vAVHf_jOOw4Tc'
# API_KEY = 'AIzaSyBVNz9Z0cC_Rb0em6oZ2f-iANBuZBda6N0'


save_address = []
# save address to save_address list where address obtained from google map api
for i in range(len(df_income)):
    
    project_name = df_income["Project Name"][i]
    zip_code = int(df_income["Zip Code"][i])

    if zip_code == 0:
        project_name = project_name
    else:
        project_name = f"{project_name} {zip_code:05d}"

    response = requests.get(url,params={"input": project_name,"inputtype":"textquery","key":API_KEY,"fields": "formatted_address"})
    candidates = response.json()["candidates"]
    try:
        address = candidates[0]["formatted_address"]
    except:
        address = ''
    print(i,address)
    save_address.append(address)

# add address column in income restricted dataframe
df_income['address'] = save_address
# save new income restricted dataset 
df_income.to_csv('data/income-restricted-inventory-address.csv',index=None,encoding='utf_8_sig')
# read new income restricted dataset
df_income = pd.read_csv('data/income-restricted-inventory-address.csv',encoding='utf_8_sig')
# Out:
# 0 100 Shawmut Ave, Boston, MA 02118, United States
# 1 1592 Columbus Ave, Roxbury, MA 02119, United States
# 2 2926 Washington St, Roxbury, MA 02119, United States
# 3
# 4
# 5 445 Adams St, Dorchester, MA 02122, United States
# 6 35 Lomasney Way, Boston, MA 02114, United States
# 7 36 Alexander St, Boston, MA 02125, United States
# 8
# 9 150 Dorchester Ave, Boston, MA 02127, United States
# 10
# 11 Alpine St, Boston, MA 02136, USA
# 12 64 American Legion Hwy, Boston, MA 02124, United States
# 13 284 Amory St, Boston, MA 02130, United States
# 14 245 Amory St, Boston, MA 02130, USA
# 15 Amory Terrace, Boston, MA 02119, USA
# 16 65 Martha Rd, Boston, MA 02114, United States
# 17 250 Cambridge St # 1, Boston, MA 02114, United States
# 18
# 19 235 Old Colony Ave, Boston, MA 02127, United States
# 20
# 21
# 22 200 Archdale Rd, Boston, MA 02131, USA
# 23 660 Washington St, Boston, MA 02111, United States
# 24 380 Bunker Hill St, Charlestown, MA 02129, United States
# 25 228 Ashmont St, Boston, MA 02124, USA
# 26 1916 Dorchester Ave, Dorchester, MA 02124, United States
# 27 217 Elizabeth St, New York, NY 10012, United States
# 28 280 Congress St, Boston, MA 02210, United States
# 29 156 Porter St, Boston, MA 02128, United States
# 30 Audubon Circle, Boston, MA 02215, United States
# 31
# 32 45 Stuart St, Boston, MA 02116, United States
# 33 1 Nashua St, Boston, MA 02114, United States
# 34 780 Boylston St, Boston, MA 02199, United States
# 35 42 Beach St, Boston, MA 02111, United States
# 36 101 Canal St, Boston, MA 02114, United States
# 37 Avondale St, Boston, MA 02124, USA
# 38 270 Babcock St, Boston, MA 02215, United States
# 39 100 S Huntington Ave, Jamaica Plain, MA 02130, United States
# 40 100 S Huntington Ave, Boston, MA 02130, United States
# 41
# 42 1243 Adams St, Boston, MA 02124, United States
# 43 434 Massachusetts Ave Suite 201, Boston, MA 02118, United States
# 44 13 Shetland St, Boston, MA 02119, United States
# 45
# 46 154 Green St, Boston, MA 02130, United States
# 47 Boston, MA 02128, United States
# 48 2565 Washington St, Boston, MA 02119, United States
# 49 2565 Washington St, Boston, MA 02119, United States
# 50 106 13th St #110, Boston, MA 02129, United States
# 51 731 Harrison Ave, Boston, MA 02118, United States
# 52 39 Glencliff Rd, Boston, MA 02131, United States
# 53 66 Canal St, Boston, MA 02114, United States
# 54 44 Fairmount St, Boston, MA 02124, United States
# 55 39 Glencliff Rd, Boston, MA 02131, United States
# 56 30 Bower St, Boston, MA 02119, United States
# 57 19 Myrtle St #208, Boston, MA 02114, United States
# 58
# 59 446 Belgrade Ave, West Roxbury, MA 02132, United States
# 60 2 Bellflower St, Boston, MA 02125, USA
# 61 125 High St #531, Boston, MA 02110, United States
# 62 Beryl St, Boston, MA 02131, USA
# 63
# 64 587 Washington St, Dorchester Center, MA 02124, United States
# 65
# 66 129 Amory St, Roxbury, MA 02119, United States
# 67 637 Washington St, Boston, MA 02124, United States
# 68 50 Freeman St, Dorchester, MA 02122, United States
# 69 706 Huntington Ave, Boston, MA 02115, United States
# 70 100-102 Hano St, Boston, MA 02134, United States
# 71 150 American Legion Hwy, Dorchester, MA 02124, United States
# 72 320 Blue Hill Avenue # B, Boston, MA 02121, United States
# 73 330 M.L.K. Jr Blvd, Boston, MA 02119, United States
# 74 35 Westland Ave, Boston, MA 02115, United States
# 75
# 76 500 Columbia Rd, Dorchester, MA 02125, United States
# 77 33 Blossom St, Boston, MA 02114, United States
# 78 1344 Hyde Park Ave, Hyde Park, MA 02136, United States
# 79 1344 Hyde Park Ave, Hyde Park, MA 02136, United States
# 80
# 81 31 Germania Street, Building A, Jamaica Plain, MA 02130, United States
# 82 Bloomfield St, Boston, MA 02124, USA
# 83 Blue Hill Commons Condominiums, 3000 Davenport Ave, Canton, MA 02021, USA
# 84 457 Blue Hill Avenue, Boston, MA 02126, United States
# 85 301 Border St, Boston, MA 02128, United States
# 86 126 Border St, Boston, MA 02128, United States
# 87 474 Commonwealth Ave, Boston, MA 02215, United States
# 88 Boston, MA 02135, United States
# 89 300 Longwood Ave, Boston, MA 02115, United States
# 90 1515 VFW Pkwy, West Roxbury, MA 02132, United States
# 91 65-85 E India Row, Boston, MA 02110, United States
# 92 71 Kingsdale St, Dorchester Center, MA 02124, United States
# 93
# 94 200 Bowdoin St, Dorchester, MA 02122, United States
# 95 Bowdoin St, Boston, MA 02114, USA
# 96 45 Myrtle St, Boston, MA 02114, United States
# 97 200 Bowdoin St, Dorchester, MA 02122, United States
# 98 200 Bowdoin St, Dorchester, MA 02122, United States
# 99 200 Bowdoin St, Dorchester, MA 02122, United States
# 100 200 Bowdoin St, Dorchester, MA 02122, United States
# 101 22 Boston Wharf Rd, Boston, MA 02210, United States
# 102 Boylston St, Boston, MA 02116, USA
# 103 180 Brookline Ave, Boston, MA 02215, United States
# 104
# 105 Bradlee St, Boston, MA 02124, USA
# 106 340 Shawmut Ave, Boston, MA 02118, United States
# 107 88 Brandywyne Dr, East Boston, MA 02128, United States
# 108
# 109
# 110 251 Heath St, Jamaica Plain, MA 02130, United States
# 111 57 Everett St N, Allston, MA 02134, United States
# 112 Brighton Ave, Boston, MA, USA
# 113 57 Everett St N, Allston, MA 02134, United States
# 114 677 Cambridge St, Brighton, MA 02135, United States
# 115
# 116 147 Moreland St, Roxbury, MA 02119, United States
# 117
# 118 Brookside Ave, Boston, MA 02130, USA
# 119 2 Brookview St #1, Dorchester Center, MA 02124, United States
# 120 2 Brookview St #1, Dorchester Center, MA 02124, United States
# 121 2 Brookview St #1, Dorchester Center, MA 02124, United States
# 122
# 123
# 124 754 Blue Hill Avenue, Dorchester, MA 02121, United States
# 125 163 W Springfield St # A, Boston, MA 02118, United States
# 126 Brunswick St, Boston, MA 02121, USA
# 127 Brush Hill Rd, Milton, MA, USA
# 128 645 Beacon St, Boston, MA 02215, United States
# 129 587 Washington St, Dorchester Center, MA 02124, United States
# 130 2273 Dorchester Ave, Boston, MA 02124, United States
# 131 530 Columbia Rd, Boston, MA 02125, United States
# 132
# 133 9820 62nd Dr, Flushing, NY 11374, United States
# 134 450 Washington St, Boston, MA 02124, United States
# 135
# 136 104 1st Ave, Charlestown, MA 02129, United States
# 137 33 3rd Ave, Boston, MA 02129, United States
# 138 Burbank St, Boston, MA 02115, USA
# 139 1575 Tremont St #1107, Boston, MA 02120, United States
# 140 337 Newbury St, Boston, MA 02115, United States
# 141 31 Germania Street, Building A, Jamaica Plain, MA 02130, United States
# 142 Callender St, Boston, MA 02124, USA
# 143 Callender St, Boston, MA 02124, USA
# 144 Callender St, Boston, MA 02124, USA
# 145
# 146 Callender St, Boston, MA 02124, USA
# 147 Callender St, Boston, MA 02124, USA
# 148 Callender St, Boston, MA 02124, USA
# 149 Callender St, Boston, MA 02124, USA
# 150 Callender St, Boston, MA 02124, USA
# 151 Callender St, Boston, MA 02124, USA
# 152 Callender St, Boston, MA 02124, USA
# 153 Callender St, Boston, MA 02124, USA
# 154
# 155 200 Camden St, Boston, MA 02118, USA
# 156 The Paulette K Ford Community Center 85 Lenox Street Paulette, Ford Way, Boston, MA 02118, United States
# 157 Capen St, Boston, MA 02124, USA
# 158
# 159 11 Woodcliff St, Boston, MA 02125, United States
# 160 289 Centre St, Dorchester, MA 02122, United States
# 161 289 Centre St, Dorchester, MA 02122, United States
# 162 28 Mt Pleasant Ave, Boston, MA 02119, United States
# 163 2055 Columbus Ave, Roxbury, MA 02119, United States
# 164 256 Marginal St, Boston, MA 02128, United States
# 165 Carol Ave, Boston, MA 02135, USA
# 166 45 Francis St, Boston, MA 02115, United States
# 167 543 Southern Artery, Quincy, MA 02169, United States
# 168 34 Parker St, Chelsea, MA 02150, United States
# 169 302 Eustis St, Boston, MA 02119, United States
# 170 130 Endicott St, Boston, MA 02113, United States
# 171 53 Glen Rd, Boston, MA 02130, United States
# 172
# 173
# 174 484 Tremont St, Boston, MA 02116, United States
# 175 1400 Washington St, Boston, MA 02118, United States
# 176 209 Heath St, Jamaica Plain, MA 02130, United States
# 177
# 178 2315 Washington St, Boston, MA 02119, United States
# 179 Centre St & Lamartine St, Boston, MA 02130, USA
# 180
# 181 7 Sachem St, Boston, MA 02120, United States
# 182 35 Channel Center St, Boston, MA 02210, United States
# 183 1 Black Falcon Ave, Boston, MA 02210, United States
# 184 61 Eutaw St, Boston, MA 02118, United States
# 185 28 N Charlame Ct, Roxbury, MA 02119, United States
# 186 28 N Charlame Ct, Roxbury, MA 02119, United States
# 187
# 188 Charles St, Boston, MA 02129, USA
# 189 650 Huntington Ave, Boston, MA 02115, United States
# 190 2 US-1, Revere, MA 02151, USA
# 191 100 Ferrin St, Charlestown, MA 02129, United States
# 192 1st Ave &, 3rd St, Boston, MA 02129, United States
# 193 Litchfield St, Boston, MA 02134, United States
# 194 115 Chauncy St #1740, Boston, MA 02111, United States
# 195 20 Cheriton Rd, West Roxbury, MA 02132, United States
# 196 Chestnut Ave, Boston, MA 02130, USA
# 197 Chestnut Hill Ave, Massachusetts, USA
# 198 Chestnut Hill Ave, Massachusetts, USA
# 199 2450 Beacon St, Chestnut Hill, MA 02467, United States
# 200 10 Moore St, Boston, MA 02128, United States
# 201 230 Harrison Ave, Boston, MA 02111, United States
# 202 Church St, Boston, MA 02122, USA
# 203 42 Park St, Charlestown, MA 02129, United States
# 204 Clarendon St, Boston, MA 02116, USA
# 205 400 Stuart St, Boston, MA 02116, United States
# 206 Cleaves St, Boston, MA 02119, USA
# 207 1 Cliffmont St, Boston, MA 02131, United States
# 208
# 209 Codman Commons, 360 Talbot Ave, Boston, MA 02124, USA
# 210 587 Washington St, Boston, MA 02124, United States
# 211
# 212 562 Columbia Rd, Dorchester, MA 02125, United States
# 213 392 Columbia Rd #10, Dorchester, MA 02125, United States
# 214 173 Columbia Rd #173, Dorchester, MA 02121, United States
# 215 1284 Commonwealth Ave, Allston, MA 02134, United States
# 216 376 Warren St, Boston, MA 02119, United States
# 217
# 218 1144-1160 Commonwealth Ave, Boston, MA 02134, United States
# 219 725 Tremont St, Boston, MA 02118, United States
# 220 725 Tremont St, Boston, MA 02118, United States
# 221 54 Orleans St # 1, East Boston, MA 02128, United States
# 222 219 Western Ave, Allston, MA 02134, United States
# 223 1 Conway St, Roslindale, MA 02131, United States
# 224 99 Border St, Boston, MA 02128, United States
# 225 99 Border St, Boston, MA 02128, United States
# 226 Cortes St, Boston, MA 02116, USA
# 227 519 Tremont St, Boston, MA 02116, United States
# 228 820 Cummins Hwy, Mattapan, MA 02126, United States
# 229 622 Dudley St, Boston, MA 02125, United States
# 230 2315 Washington St, Boston, MA 02119, United States
# 231 Court St, Boston, MA 02108, USA
# 232 Fellsway St &, Milton St, Dorchester, MA 02124, United States
# 233 30 Washington St, Boston, MA 02135, United States
# 234 Bartlett St &, Dudley St, Boston, MA 02119, United States
# 235 86 Crawford St, Dorchester, MA 02121, United States
# 236 241 Perkins St, Boston, MA 02130, United States
# 237 10 Perthshire Rd, Boston, MA 02135, United States
# 238 855 American Legion Hwy, Roslindale, MA 02131, United States
# 239 650 Harrison Ave, Boston, MA 02118, United States
# 240
# 241 Boston, MA 02124, United States
# 242
# 243 39 Zeigler St, Boston, MA 02119, United States
# 244 185 Dartmouth St 9th floor, Boston, MA 02116, United States
# 245 Davenport Commons A, 700 Columbus Ave, Boston, MA 02120, USA
# 246
# 247
# 248
# 249 Derne St, Boston, MA 02114, USA
# 250 453 Washington St, Boston, MA 02111, United States
# 251
# 252 955 Boylston St, Boston, MA 02115, United States
# 253 27 Dimock St, Boston, MA 02119, United States
# 254
# 255
# 256 383 Dorchester Ave, Boston, MA 02127, United States
# 257 25 Ditson St, Dorchester, MA 02122, United States
# 258 944 Dorchester Ave, Boston, MA 02125, United States
# 259
# 260
# 261 1353 Dorchester Ave, Dorchester, MA 02122, United States
# 262 Douglass Park, Boston, MA 02118, USA
# 263 135 E Berkeley St, Boston, MA 02118, United States
# 264 Drayton Ave, Boston, MA 02125, USA
# 265 225 Dudley St, Roxbury, MA 02119, United States
# 266 225 Dudley St, Roxbury, MA 02119, United States
# 267 Dudley Terrace, Boston, MA 02125, USA
# 268
# 269
# 270
# 271 Dunmore St, Boston, MA 02119, USA
# 272 477 Harrison Ave, Boston, MA 02118, United States
# 273 52 White St, Boston, MA 02128, United States
# 274 E Berkeley St, Boston, MA 02118, USA
# 275 109 E Canton St, Boston, MA 02118, United States
# 276 30 Northampton St, Boston, MA 02118, United States
# 277 The Courtyard By Marriot, 63R Boston St, Boston, MA 02125, United States
# 278 133, 135 Seaport Blvd, Boston, MA 02210, United States
# 279 Edison Green, Boston, MA 02125, USA
# 280 Edson St, Boston, MA 02124, USA
# 281 30 Milton Ave, Dorchester Center, MA 02124, USA
# 282 256 Boston St, Dorchester, MA 02125, United States
# 283 2010 Columbus Ave, Roxbury, MA 02119, United States
# 284
# 285 3012 Washington St, Roxbury, MA 02119, United States
# 286 Boston, MA 02121, United States
# 287 Elven Rd, Boston, MA 02131, USA
# 288 1 Emerson Pl Apt 8N, Boston, MA 02114, United States
# 289
# 290 31 Erie St, Boston, MA 02121, United States
# 291 80-84 Walnut Ave, Boston, MA 02119, United States
# 292 630 Tremont St, Boston, MA 02118, United States
# 293 Eutaw St & Meridian St, Boston, MA 02128, USA
# 294 440 Tremont St UNIT 108, Boston, MA 02116, United States
# 295 63 Melcher St, Boston, MA 02210, United States
# 296 219 Newbury St, Boston, MA 02116, United States
# 297
# 298 Fan Pier Boulevard, Boston, MA 02110, USA
# 299 10 Fan Pier Boulevard Mailbox #26, Boston, MA 02210, United States
# 300 266 N Beacon St #52, Brighton, MA 02135, United States
# 301 90 South St, Jamaica Plain, MA 02130, United States
# 302
# 303
# 304
# 305 Fenway Center, 77 St Stephen St, Boston, MA 02115, USA
# 306 41-43 Westland Ave, Boston, MA 02115, United States
# 307 108 Peterborough St, Boston, MA 02215, United States
# 308 4 Jersey St, Boston, MA 02215, United States
# 309
# 310 907 Blue Hill Avenue # 13, Dorchester Center, MA 02124, United States
# 311 136 H St, South Boston, MA 02127, United States
# 312 132 Fawndale Rd, Roslindale, MA 02131, United States
# 313
# 314 545 Centre St, Jamaica Plain, MA 02130, United States
# 315 545 Centre St, Jamaica Plain, MA 02130, United States
# 316 26 Seyon St, Waltham, MA 02453, United States
# 317 121 Portland St, Boston, MA 02114, United States
# 318 106 Forest Hills St, Jamaica Plain, MA 02130, United States
# 319 95 Hyde Park Ave, Boston, MA 02130, United States
# 320 199 Forest Hills St, Boston, MA 02130, United States
# 321
# 322
# 323 Fort Ave, Boston, MA 02119, USA
# 324 Fort Point, Boston, MA, USA
# 325
# 326 Fountain St, Boston, MA 02119, USA
# 327 345 Washington St # 1, Dorchester, MA 02121, United States
# 328
# 329
# 330 Franklin Field South, Boston, MA, USA
# 331
# 332 2 Franklin Hill Ave, Boston, MA 02124, USA
# 333 132 Seaver St #1527, Boston, MA 02121, United States
# 334 1 Franklin Park Rd, Boston, MA 02121, United States
# 335 1 Franklin Park Rd, Boston, MA 02121, United States
# 336 1575 Tremont St, Boston, MA 02120, United States
# 337 755 Tremont St, Boston, MA 02118, United States
# 338 6-8 Chestnut St, Boston, MA 02108, United States
# 339 100 Fulton St #1m, Boston, MA 02109, United States
# 340 200 Gallivan Blvd, Boston, MA 02124, USA
# 341
# 342 9 Gardner St, Allston, MA 02134, United States
# 343
# 344
# 345 75 W School St, Charlestown, MA 02129, United States
# 346 75 W School St, Charlestown, MA 02129, United States
# 347 40 Fay St H-601, Boston, MA 02118, United States
# 348 61 Heath St, Jamaica Plain, MA 02130, United States
# 349 47 N Washington St #26, Charlestown, MA 02129, United States
# 350 231 Geneva Ave, Boston, MA 02121, United States
# 351 202 Geneva Ave, Boston, MA 02121, USA
# 352 22 Beechwood St, Dorchester, MA 02121, United States
# 353 400 Georgetowne Dr, Hyde Park, MA 02136, United States
# 354 400 Georgetowne Dr, Hyde Park, MA 02136, United States
# 355 489 Blue Hill Avenue, Dorchester, MA 02121, United States
# 356 1285 Commonwealth Ave, Allston, MA 02134, United States
# 357
# 358 165 Chestnut St, Brookline, MA 02445, United States
# 359 1100 Washington St, Dorchester, MA 02124, United States
# 360 Goodale Rd, Boston, MA 02126, USA
# 361
# 362 209 Kelton St, Allston, MA 02134, United States
# 363
# 364
# 365 754 Blue Hill Avenue, Dorchester, MA 02121, United States
# 366 754 Blue Hill Avenue, Dorchester, MA 02121, United States
# 367 115 E Cottage St, Boston, MA 02125, United States
# 368 218 Adams St, Boston, MA 02122, United States
# 369 San Diego 300, Lima 15047, Peru
# 370 754 Blue Hill Avenue, Dorchester, MA 02121, United States
# 371 320 Blue Hill Avenue # B, Boston, MA 02121, United States
# 372 3230 Washington St, Boston, MA 02130, United States
# 373 173 Columbia Rd #173, Dorchester, MA 02121, United States
# 374 1810 Washington St, Boston, MA 02118, United States
# 375 20 Newton St, Brookline, MA 02445, United States
# 376
# 377 172 Maverick St, Boston, MA 02128, United States
# 378 12 Castlegate Rd #9, Dorchester, MA 02121, United States
# 379
# 380
# 381 451 Arrowhead Park Rd, Huntsville, ON P1H 2J4, Canada
# 382 434 Massachusetts Ave Suite 201, Boston, MA 02118, United States
# 383 1580 VFW Pkwy, West Roxbury, MA 02132, United States
# 384 1580 VFW Pkwy, West Roxbury, MA 02132, United States
# 385 1580 VFW Pkwy, West Roxbury, MA 02132, United States
# 386 434 Massachusetts Ave Suite 201, Boston, MA 02118, United States
# 387 1580 VFW Pkwy, West Roxbury, MA 02132, United States
# 388 273 Clarendon St, Boston, MA 02116, United States
# 389 23 Dartmouth St, Boston, MA 02116, United States
# 390 444 Harrison Ave, Boston, MA 02118, United States
# 391 Hammond St, Boston, MA 02120, USA
# 392 155 Northampton St, Boston, MA 02118, United States
# 393 60 Hano St, Boston, MA 02134, United States
# 394
# 395 Harbor Point Blvd, Boston, MA 02125, USA
# 396 10 Orleans St, East Boston, MA 02128, United States
# 397
# 398 Harrison Ave, Boston, MA 02118, USA
# 399 300 Harrison Ave, Boston, MA 02118, United States
# 400
# 401 Hartwell St, Boston, MA 02121, USA
# 402 6 Snowden Way, Boston, MA 02124, United States
# 403 705 River St, Boston, MA 02136, United States
# 404 3 Hazel St, Waltham, MA 02451, United States
# 405 16 Ronald St, Boston, MA 02121, United States
# 406 Hummingbird Ln, Boston, MA 02126, United States
# 407 768 Huntington Ave, Boston, MA 02115, United States
# 408 209 Sumner St, Boston, MA 02128, United States
# 409 300 Boylston St, Boston, MA 02116, United States
# 410 981 Morton St, Boston, MA 02126, United States
# 411 58 Beech Glen St, Boston, MA 02119, United States
# 412 125 Highland St, Boston, MA 02119, United States
# 413
# 414 607 Boylston St #500, Boston, MA 02116, United States
# 415 2926 Washington St, Roxbury, MA 02119, United States
# 416 131 Morton St, Jamaica Plain, MA 02130, United States
# 417 792 Tremont St #1051, Boston, MA 02118, United States
# 418 18 Tremont St Suite 500, Boston, MA 02108, United States
# 419
# 420 40 School St, Boston, MA 02124, United States
# 421 100 S Huntington Ave, Jamaica Plain, MA 02130, United States
# 422 69 Alleghany St, Roxbury, MA 02120, United States
# 423 230 Shawmut Ave, Boston, MA 02118, United States
# 424 1448 Dorchester Ave, Boston, MA 02122, United States
# 425 8 Farnham St, Boston, MA 02119, United States
# 426 8 Farnham St, Boston, MA 02119, United States
# 427 Capen St, Boston, MA 02124, USA
# 428 1601 Blue Hill Avenue #205, Mattapan, MA 02126, United States
# 429 16 Dacia St, Dorchester, MA 02125, United States
# 430
# 431 25 Morrissey Blvd, Boston, MA 02125, United States
# 432 278 Humboldt Ave, Dorchester, MA 02121, United States
# 433 160 Federal St # 2, Boston, MA 02110, United States
# 434 25 Morrissey Blvd, Boston, MA 02125, United States
# 435 11 Humphreys St # 1, Dorchester, MA 02125, United States
# 436
# 437 VA Medical Center, 150 S Huntington Ave, Boston, MA 02130, United States
# 438 2500 Washington St, Roxbury, MA 02119, United States
# 439 390-401 Centre St, Jamaica Plain, MA 02130, United States
# 440 91 Minden St, Jamaica Plain, MA 02130, United States
# 441 91 Minden St, Jamaica Plain, MA 02130, United States
# 442 450 Hyde Park Ave, Roslindale, MA 02131, United States
# 443
# 444 1208B VFW Pkwy STE 301, Boston, MA 02132, United States
# 445 67 E Cottage St, Boston, MA 02125, United States
# 446 17 Wensley St, Boston, MA 02120, United States
# 447
# 448
# 449
# 450
# 451 300 Harrison Ave, Boston, MA 02118, United States
# 452 300 Harrison Ave, Boston, MA 02118, United States
# 453 40 Traveler St, Boston, MA 02118, United States
# 454 282 Columbus Ave, Boston, MA 02116, United States
# 455 301 Columbia Rd, Dorchester, MA 02121, United States
# 456 Intervale St, Boston, MA 02121, USA
# 457 Intervale St & Magnolia St, Boston, MA 02121, USA
# 458
# 459
# 460
# 461 1542 Columbus Ave, Boston, MA 02119, United States
# 462 Blue Hill Avenue, Boston, MA 02121, United States
# 463 24 Lawn St B, Boston, MA 02130, United States
# 464 131 Morton St, Jamaica Plain, MA 02130, United States
# 465 30 Wallingford Rd, Brighton, MA 02135, United States
# 466 John Boyle O'Reilly School Management, 345 Dorchester St, South Boston, MA 02127, USA
# 467
# 468
# 469 90 Bickford St, Boston, MA 02130, United States
# 470
# 471 330 Fuller St, Dorchester Center, MA 02124, United States
# 472
# 473
# 474 89 Fort Ave, Boston, MA 02119, United States
# 475 490 Commonwealth Ave, Boston, MA 02215, United States
# 476 160 Dudley St, Roxbury, MA 02119, United States
# 477 151 Hallet St, Boston, MA 02124, United States
# 478 75 Francis St, Boston, MA 02115, United States
# 479 Alvah Kittredge Park, Boston, MA 02119, USA
# 480 D St, Boston, MA 02127, United States
# 481 1200 Washington St, Boston, MA 02118, United States
# 482
# 483 155 Lamartine St, Jamaica Plain, MA 02130, United States
# 484 1501 Commonwealth Ave, Brighton, MA 02135, United States
# 485 401 Border St, Boston, MA 02128, United States
# 486 401 Border St, Boston, MA 02128, United States
# 487 26 Worcester St, Boston, MA 02118, United States
# 488
# 489 431 Melnea Cass Blvd, Boston, MA 02119, United States
# 490
# 491 205 Townsend St, Boston, MA 02121, United States
# 492 77 Lawrence Ave, Dorchester, MA 02121, United States
# 493 Lawrence St, Boston, MA 02116, USA
# 494 193 Talbot Ave, Boston, MA 02124, United States
# 495
# 496 2 Lenox St, Boston, MA 02118, USA
# 497
# 498 28 Wallingford Rd, Brighton, MA 02135, United States
# 499 5 Lewis Mall, Boston, MA 02128, USA
# 500 191 Talbot Ave, Boston, MA 02124, United States
# 501 101 Chestnut St, Boston, MA 02108, United States
# 502 1 Westinghouse Plaza Building C, Hyde Park, MA 02136, United States
# 503 75 St Alphonsus St, Boston, MA 02120, United States
# 504 1285 Commonwealth Ave, Allston, MA 02134, United States
# 505 1285 Commonwealth Ave, Allston, MA 02134, United States
# 506 885 South St, Boston, MA 02131, United States
# 507 1 Sewall St, Boston, MA 02120, United States
# 508 270 Roxbury St, Roxbury, MA 02119, United States
# 509 65 Martha Rd, Boston, MA 02114, United States
# 510 2269 Dorchester Ave, Boston, MA 02124, United States
# 511 11 New Whitney St, Boston, MA 02115, United States
# 512 65 Winston Rd, Boston, MA 02124, United States
# 513 145 Ipswich St, Boston, MA 02215, United States
# 514 100 Huntington Ave Level 1, Boston, MA 02116, United States
# 515 30 Polk St, Boston, MA 02129, United States
# 516 10 Moore St, Boston, MA 02128, United States
# 517 840 Harrison Ave 1st Floor, Boston, MA 02118, United States
# 518 7 Sterling Square, Boston, MA 02127, United States
# 519 158 Walnut Ave, Boston, MA 02119, United States
# 520
# 521 600 Melnea Cass Blvd, Boston, MA 02119, United States
# 522
# 523 122 Dewitt Dr, Boston, MA 02120, United States
# 524 184 Dudley St #102, Boston, MA 02119, United States
# 525 338 Main St, Boston, MA 02129, United States
# 526 29 Crafts St #260, Newton, MA 02458, United States
# 527
# 528 1855 Washington St, Boston, MA 02118, United States
# 529
# 530 15 Maple St, Boston, MA 02121, United States
# 531 Managers Office, 44 John Eliot Sq, Boston, MA 02119, United States
# 532 95 Humboldt Ave # A, Dorchester, MA 02121, United States
# 533 The Schrafft Center, 529 Main St #201, Charlestown, MA 02129, United States
# 534
# 535 20 Devens St, Charlestown, MA 02129, United States
# 536 Mason St, Boston, MA 02111, United States
# 537 336B Tremont St, Boston, MA 02116, United States
# 538 725-735 Adams St, Boston, MA 02122, United States
# 539 555 River St, Mattapan, MA 02126, United States
# 540 229A River St, Mattapan, MA 02126, United States
# 541 229A River St, Mattapan, MA 02126, United States
# 542 229A River St, Mattapan, MA 02126, United States
# 543 31 Liverpool St, East Boston, MA 02128, United States
# 544 31 Liverpool St, East Boston, MA 02128, United States
# 545
# 546 10 Maple Pl, Boston, MA 02111, United States
# 547
# 548
# 549 111 Atlantic Ave, Boston, MA 02110, United States
# 550 408 Meridian St, East Boston, MA 02128, United States
# 551 Meridian St, Boston, MA 02128, USA
# 552 405 Columbus Ave #101, Boston, MA 02116, United States
# 553 30 Caldwell St, Charlestown, MA 02129, United States
# 554 43 Smith St, Boston, MA 02120, United States
# 555
# 556
# 557
# 558
# 559
# 560
# 561
# 562 15 Channel Center St, Boston, MA 02210, United States
# 563 15 Channel Center St, Boston, MA 02210, United States
# 564 850 Albany St, Roxbury, MA 02119, United States
# 565 1102 Washington St, Boston, MA 02118, United States
# 566 15 Park Dr, Boston, MA 02215, United States
# 567 197 8th St #900, Charlestown, MA 02129, United States
# 568 338 Main St, Boston, MA 02129, United States
# 569 1457 Tremont St, Boston, MA 02120, United States
# 570
# 571 1620 Tremont St #2nd, Boston, MA 02120, United States
# 572 1620 Tremont St #2nd, Boston, MA 02120, United States
# 573 1620 Tremont St #2nd, Boston, MA 02120, United States
# 574 43 Smith St, Boston, MA 02120, United States
# 575 43 Smith St, Boston, MA 02120, United States
# 576 43 Smith St, Boston, MA 02120, United States
# 577 835 Huntington Ave, Boston, MA 02115, United States
# 578 285 M.L.K. Jr Blvd, Boston, MA 02119, United States
# 579 40 Traveler St, Boston, MA 02118, United States
# 580
# 581
# 582 111 Perkins St, Boston, MA 02130, United States
# 583 272 Itasca St, Boston, MA 02126, United States
# 584 13 Shetland St, Boston, MA 02119, United States
# 585 65 Morton Village Dr, Boston, MA 02126, United States
# 586 65 Morton Village Dr, Boston, MA 02126, United States
# 587 100 Norway St, Boston, MA 02115, United States
# 588 401 Mt Vernon St, Boston, MA 02125, United States
# 589 230 Lee Burbank Hwy, Revere, MA 02151, United States
# 590
# 591 70 Perkins St, Somerville, MA 02145, United States
# 592 301 S Huntington Ave, Jamaica Plain, MA 02130, United States
# 593 31 Erie St, Boston, MA 02121, United States
# 594
# 595 36 Traveler St Unit 1, Boston, MA 02118, United States
# 596 1 Nashua St, Boston, MA 02114, United States
# 597 155 Lamartine St, Jamaica Plain, MA 02130, United States
# 598 232 Seaver St, Boston, MA 02121, United States
# 599 125 Parker Hill Ave, Boston, MA 02120, United States
# 600 399 Congress St, Boston, MA 02210, United States
# 601 29 Neponset Field Ln, Hyde Park, MA 02136, United States
# 602 24 Oakton Ave, Dorchester, MA 02122, United States
# 603 24 Oakton Ave, Dorchester, MA 02122, United States
# 604 24 Oakton Ave, Dorchester, MA 02122, United States
# 605 24 Oakton Ave, Dorchester, MA 02122, United States
# 606
# 607
# 608 24 Oakton Ave, Dorchester, MA 02122, United States
# 609 530 Warren St, Boston, MA 02121, United States
# 610 Newcastle Ct, Boston, MA 02118, USA
# 611 339 Talbot Ave, Boston, MA 02124, United States
# 612 2 Atlantic Ave #2, Boston, MA 02110, United States
# 613
# 614 Norfolk St, Boston, MA 02126, USA
# 615 14 Porter St, East Boston, MA 02128, United States
# 616 269 Washington Ave, Chelsea, MA 02150, United States
# 617 Northampton St, Boston, MA 02118, USA
# 618 35 Northampton St, Boston, MA 02118, United States
# 619 1-31 Northampton St, Boston, MA 02118, United States
# 620 30 Hemenway St, Boston, MA 02115, United States
# 621 Norwell St, DORCHESTR CTR, MA 02124, USA
# 622
# 623 1235 VFW Pkwy, West Roxbury, MA 02132, United States
# 624 Oak St, Boston, MA 02111, USA
# 625 O'Connor Way, Boston, MA 02127, USA
# 626 270 Centre St, Jamaica Plain, MA 02130, United States
# 627 224 Old Colony Ave, Boston, MA 02127, USA
# 628 Old Colony Ave, Boston, MA 02127, USA
# 629 55 Fruit St # 410, Boston, MA 02114, United States
# 630 Hummingbird Ln, Boston, MA 02126, United States
# 631 Hummingbird Ln, Boston, MA 02126, United States
# 632 Hummingbird Ln, Boston, MA 02126, United States
# 633 Hummingbird Ln, Boston, MA 02126, United States
# 634 Hummingbird Ln, Boston, MA 02126, United States
# 635 Olmsted Rd, Brookline, MA 02445, USA
# 636 15 Essex St, Boston, MA 02111, United States
# 637 1 Canal St, Boston, MA 02114, United States
# 638 1 Canal St, Boston, MA 02114, United States
# 639 99 Kneeland St, Boston, MA 02111, United States
# 640
# 641 10 Lincoln St, Boston, MA 02111, United States
# 642 1 Newcomb St, Boston, MA 02118, United States
# 643 906 Albany St, Boston, MA 02119, United States
# 644
# 645 District of Freedom#8573311~!#, Boston, MA 02128, United States
# 646
# 647
# 648 14-14A Oxford St, Boston, MA 02111, United States
# 649 Oxford Pl, Boston, MA 02111, USA
# 650 79-83 Gardner St, Boston, MA 02134, United States
# 651
# 652 Boston, MA 02120, United States
# 653
# 654
# 655
# 656
# 657
# 658 Paris St, Boston, MA 02128, USA
# 659 25 District Ave, Dorchester, MA 02125, United States
# 660 526 Park St, Dorchester, MA 02124, United States
# 661 Leslie Park, Boston, MA 02119, USA
# 662
# 663 170 Parker Hill Ave, Boston, MA 02120, United States
# 664 4236 Washington St, Boston, MA 02131, United States
# 665
# 666 1782 Washington St, Boston, MA 02118, United States
# 667
# 668 330 Bowdoin St, Boston, MA 02122, United States
# 669
# 670
# 671
# 672
# 673 195-197 Ashmont St, Boston, MA 02124, United States
# 674
# 675 25 Penniman Rd, Boston, MA 02134, United States
# 676 30 Un Park St, Boston, MA 02118, United States
# 677
# 678 1284 Blue Hill Avenue, Mattapan, MA 02126, United States
# 679 78 Peterborough St # 11, Boston, MA 02215, United States
# 680 311 Bowdoin St, Boston, MA 02122, United States
# 681 1 Harvard Yard, Cambridge, MA 02138, United States
# 682 Roxbury Crossing,, 166 Terrace St, Roxbury Crossing, MA 02120, United States
# 683 444 Harrison Ave, Boston, MA 02118, United States
# 684 444 Harrison Ave, Boston, MA 02118, United States
# 685 Pine St, Dedham, MA 02026, USA
# 686
# 687 564 Centre St, Jamaica Plain, MA 02130, United States
# 688 45 W 3rd St, Boston, MA 02127, United States
# 689 226 S Huntington Ave, Jamaica Plain, MA 02130, United States
# 690
# 691 Louis Prang St, Boston, MA 02115, United States
# 692 11 Mt Pleasant Ave # 103, Roxbury, MA 02119, United States
# 693 Putnam Pl, Boston, MA 02119, USA
# 694 1 Canton Rd #15, Quincy, MA 02171, United States
# 695 Quincy St, Boston, MA, USA
# 696 5 Oak St W, Boston, MA 02116, United States
# 697 31 Marcella St, Boston, MA 02119, United States
# 698
# 699
# 700 1950 Massachusetts Ave, Cambridge, MA 02140, United States
# 701
# 702 1925 Commonwealth Ave, Boston, MA 02135, United States
# 703 48 Bigelow Ave, Watertown, MA 02472, United States
# 704 77 Warren St, Brighton, MA 02135, United States
# 705
# 706 11 2nd New Way, Hyde Park, MA 02136, United States
# 707 39 Maple St, Hyde Park, MA 02136, United States
# 708 111 Pleasant St, Watertown, MA 02472, United States
# 709 401 Quincy St, Boston, MA 02125, United States
# 710 541 Shawmut Ave, Boston, MA 02118, United States
# 711
# 712 30 Rockingham Ave, West Roxbury, MA 02132, United States
# 713 45 Walnut Ave, Roxbury, MA 02119, United States
# 714
# 715 Rockvale Cir, Boston, MA 02130, USA
# 716
# 717 2 Rollins St, Boston, MA 02118, United States
# 718 58 13th St, Boston, MA 02129, United States
# 719 13 Marion St, Roslindale, MA 02131, United States
# 720 515 Hyde Park Ave, Boston, MA 02131, United States
# 721
# 722 1 Cliffmont St, Boston, MA 02131, United States
# 723 134 Northampton St, Roxbury, MA 02118, United States
# 724 30 Gurney St, Boston, MA 02120, United States
# 725 11 New Whitney St, Boston, MA 02115, United States
# 726 1050 Tremont St, Boston, MA 02120, United States
# 727 Prospect St, Boston, MA 02129, USA
# 728 1 Fenwood Rd, Boston, MA 02115, United States
# 729 41 Ruggles St, Roxbury, MA 02119, United States
# 730 463 Rutherford Ave, Boston, MA 02129, United States
# 731 Rutland Square, Boston, MA 02118, USA
# 732 2 E Springfield St, Boston, MA 02118, USA
# 733 434 Massachusetts Ave Suite 201, Boston, MA 02118, United States
# 734 15 Newbury St, Boston, MA 02116, United States
# 735 33 Perrin St, Boston, MA 02119, United States
# 736 Saratoga St, Massachusetts, USA
# 737
# 738 127 Pleasant St, Dorchester, MA 02125, United States
# 739 130 Auckland St, Boston, MA 02125, United States
# 740
# 741 Creston St, Boston, MA 02121, USA
# 742
# 743 111 Perkins St, Boston, MA 02130, United States
# 744 40 River St, Boston, MA 02126, United States
# 745 610 Cummins Hwy, Mattapan, MA 02126, United States
# 746
# 747 300 Harrison Ave, Boston, MA 02118, United States
# 748 1601 Washington St, Boston, MA 02118, United States
# 749 792 Tremont St #1051, Boston, MA 02118, United States
# 750 1000 Seton Dr, Orwigsburg, PA 17961, United States
# 751 78 Bennington St, Boston, MA 02128, United States
# 752 592 Tremont St, Boston, MA 02118, United States
# 753
# 754 600 Border St, East Boston, MA 02128, United States
# 755 154 W 2nd St, Boston, MA 02127, United States
# 756 Copley Square, Boston, MA 02116, United States
# 757
# 758
# 759 150 Magnolia St # A, Dorchester, MA 02125, United States
# 760
# 761 757 Shawmut Ave, Roxbury, MA 02119, United States
# 762 1100 Washington St Ste: 200-201, Dorchester Center, MA 02124, United States
# 763
# 764 1 Maple Ct B, Boston, MA 02121, United States
# 765 1205-1215 Centre St, West Roxbury, MA 02132, United States
# 766 8 Allstate Rd, Boston, MA 02118, United States
# 767 225 W 2nd St, South Boston, MA 02127, United States
# 768 120 H St, Boston, MA 02127, United States
# 769
# 770 552 W Fourth St, Boston, MA 02127, United States
# 771 285 Tremont St, Boston, MA 02116, United States
# 772 781 Tremont St, Boston, MA 02118, United States
# 773 781 Tremont St, Boston, MA 02118, United States
# 774 1601 Washington St, Boston, MA 02118, United States
# 775 163 W Springfield St # A, Boston, MA 02118, United States
# 776 23 Wellington St, Boston, MA 02118, United States
# 777 23 Wellington St, Boston, MA 02118, United States
# 778 200 South St, Boston, MA 02130, USA
# 779 110 Sudbury St, Boston, MA 02114, United States
# 780 Spencer House, Boston, MA 02119, USA
# 781
# 782 81 St Botolph St, Boston, MA 02116, United States
# 783 352 Massachusetts Ave, Boston, MA 02115, United States
# 784 81 St Botolph St, Boston, MA 02116, United States
# 785 353 Massachusetts Ave, Boston, MA 02115, United States
# 786 108 Kilmarnock St, Boston, MA 02215, United States
# 787 159 Washington St #201, Boston, MA 02135, United States
# 788 89 Un Park St, Boston, MA 02118, United States
# 789 1 St James Pl, Boston, MA 02119, United States
# 790 15 Un Park St, Boston, MA 02118, United States
# 791 86 Crispus Attucks Pl, Roxbury, MA 02119, United States
# 792 516 Columbia Rd, Boston, MA 02125, United States
# 793 75 Flaherty Way, South Boston, MA 02127, United States
# 794 50 Hichborn St, Boston, MA 02134, United States
# 795 13 Stafford St, Boston, MA 02119, United States
# 796 Stanwood St, Boston, MA 02121, USA
# 797
# 798 Audubon Circle, Boston, MA 02215, United States
# 799 97 Lamartine St, Boston, MA 02130, United States
# 800 150 Clare Ave # 6A, Hyde Park, MA 02136, United States
# 801 234 Causeway St, Boston, MA 02114, United States
# 802
# 803 74 Lawley St #1, Dorchester, MA 02122, United States
# 804 Sumner St, Boston, MA 02125, USA
# 805 76 Elm St, Jamaica Plain, MA 02130, United States
# 806
# 807
# 808
# 809
# 810
# 811
# 812
# 813
# 814
# 815
# 816
# 817
# 818
# 819
# 820
# 821
# 822
# 823
# 824
# 825
# 826
# 827
# 828
# 829
# 830
# 831
# 832
# 833
# 834
# 835
# 836
# 837
# 838
# 839
# 840
# 841
# 842 41-43 Westland Ave, Boston, MA 02115, United States
# 843 334 Massachusetts Ave, Boston, MA 02115, United States
# 844 334 Massachusetts Ave, Boston, MA 02115, United States
# 845 65R Boston St Suite 100, Dorchester, MA 02125, United States
# 846
# 847 65R Boston St Suite 100, Dorchester, MA 02125, United States
# 848 230 Harrison Ave, Boston, MA 02111, United States
# 849
# 850
# 851 193 Talbot Ave, Boston, MA 02124, United States
# 852 193 Talbot Ave, Boston, MA 02124, United States
# 853 40 Warren St, Boston, MA 02129, United States
# 854 754 Blue Hill Avenue, Dorchester, MA 02121, United States
# 855 143 Shirley St, Boston, MA 02119, United States
# 856 434 Massachusetts Ave, Boston, MA 02118, United States
# 857
# 858 404 Western Ave, Boston, MA 02134, United States
# 859
# 860
# 861
# 862
# 863
# 864
# 865
# 866
# 867
# 868
# 869
# 870
# 871
# 872
# 873
# 874 130 Dartmouth St, Boston, MA 02116, United States
# 875 587 Washington St, Boston, MA 02124, United States
# 876 90 Wareham St, Boston, MA 02118, United States
# 877 1650 Commonwealth Ave, Boston, MA 02135, United States
# 878 103 9th St, Charlestown, MA 02129, United States
# 879 4 Lucy St, Boston, MA 02125, United States
# 880 101 Beverly St, Boston, MA 02114, United States
# 881 Atlantic Ave, Boston, MA 02110, United States
# 882 111 Dartmouth St, Boston, MA 02116, United States
# 883 303 Columbus Ave, Boston, MA 02116, United States
# 884 116 Huntington Ave, Boston, MA 02116, United States
# 885 185 Massachusetts Ave, Boston, MA 02115, United States
# 886 Chester Park, Boston, MA 02118, USA
# 887 400 Stuart St, Boston, MA 02116, United States
# 888 311 Blue Hill Avenue, Boston, MA 02121, United States
# 889 199 Forest Hills St, Boston, MA 02130, United States
# 890 Boston, MA 02126, USA
# 891 283 Old Colony Ave, Boston, MA 02127, United States
# 892 32 Cambridge St, Charlestown, MA 02129, United States
# 893 2045 Dorchester Ave, Boston, MA 02124, United States
# 894 50 Hood Park Dr, Boston, MA 02129, United States
# 895 1050 Tremont St, Boston, MA 02120, United States
# 896 1501 Commonwealth Ave, Brighton, MA 02135, United States
# 897 141 Dorchester Ave, Boston, MA 02127, United States
# 898 99 Sumner St, Boston, MA 02128, United States
# 899 431 Melnea Cass Blvd, Boston, MA 02119, United States
# 900 1 Nassau St, Boston, MA 02111, United States
# 901 255 Northampton St, Roxbury, MA 02118, United States
# 902 1200 Soldiers Field Rd suite 102, Boston, MA 02134, United States
# 903 88 Constitution Rd, Boston, MA 02129, United States
# 904 200 Brookline Ave, Boston, MA 02215, United States
# 905 120 Kingston St, Boston, MA 02111, United States
# 906 95 Hyde Park Ave, Boston, MA 02130, United States
# 907
# 908 50 W Broadway, Boston, MA 02127, United States
# 909 The Residences, Boston, MA 02127, USA
# 910 250 Meridian St, Boston, MA 02128, United States
# 911 10 Temple Pl, Boston, MA 02111, United States
# 912 125 Bowker St, Boston, MA 02114, United States
# 913 1480-1482 Tremont St, Boston, MA 02120, United States
# 914 133 Columbia Rd, Boston, MA 02121, United States
# 915 Thetford Ave, Boston, MA 02124, USA
# 916 80 W Dedham St, Boston, MA 02118, United States
# 917 400 Georgetowne Dr, Hyde Park, MA 02136, United States
# 918 29 Neponset Field Ln, Hyde Park, MA 02136, United States
# 919 1971-1977 Dorchester Ave, Boston, MA 02124, United States
# 920 725 Tremont St, Boston, MA 02118, United States
# 921 Fenway Triangle Trilogy, 170 Brookline Ave, Boston, MA 02215, United States
# 922 406 Meridian St, Boston, MA 02128, United States
# 923 Trinity Terrace, Boston, MA 02121, USA
# 924 335 W 2nd St, Boston, MA 02127, United States
# 925 55 Traveler St, Boston, MA 02118, United States
# 926
# 927
# 928 3200 Washington St, Jamaica Plain, MA 02130, United States
# 929 Dixwell St, Boston, MA 02119, USA
# 930 90 Antwerp St, Boston, MA 02135, United States
# 931 Boston, MA 02135, United States
# 932 545 Columbia Rd, Dorchester, MA 02125, United States
# 933 530 Columbia Rd, Boston, MA 02125, United States
# 934 Upham's Corner, Boston, MA, USA
# 935 592 Tremont St, Boston, MA 02118, United States
# 936 592 Tremont St, Boston, MA 02118, United States
# 937 142 Berkeley St, Boston, MA 02116, United States
# 938 142 Berkeley St, Boston, MA 02116, United States
# 939
# 940
# 941 Van Ness St, Boston, MA 02215, USA
# 942 961 Morrissey Blvd, Dorchester, MA 02122, United States
# 943 77 Warren St, Brighton, MA 02135, United States
# 944 1555 VFW Pkwy, West Roxbury, MA 02132, United States
# 945 640 Tremont St, Boston, MA 02118, United States
# 946 54 Orleans St # 1, East Boston, MA 02128, United States
# 947 566 Chester Square, Boston, MA 02118, United States
# 948 42 Charles St, Boston, MA 02122, United States
# 949 1 Michelangelo St, Boston, MA 02113, United States
# 950 Stony Brook / Cleary Square, Boston, MA, USA
# 951 The Schrafft Center, 529 Main St #201, Charlestown, MA 02129, United States
# 952 1282 Boylston St, Boston, MA 02215, United States
# 953 3531 Washington St Suite 103, Jamaica Plain, MA 02130, United States
# 954 640 Tremont St, Boston, MA 02118, United States
# 955 H58H+JQP, La Joya 04406, Peru
# 956 Wait St, Boston, MA 02115, USA
# 957 161 S Huntington Ave, Jamaica Plain, MA 02130, United States
# 958 28 Wallingford Rd, Brighton, MA 02135, United States
# 959 230 Walnut St, Newtonville, MA 02460, United States
# 960 237 Walnut Ave, Boston, MA 02119, United States
# 961
# 962 1231 Adams St, Boston, MA 02124, United States
# 963
# 964 158 Walnut Ave, Boston, MA 02119, United States
# 965 90 Wareham St, Boston, MA 02118, United States
# 966 45 Stuart St, Boston, MA 02116, United States
# 967 45 Walnut Ave, Roxbury, MA 02119, United States
# 968 69 Bell Rock St #2, Malden, MA 02148, United States
# 969 321 Centre St, Dorchester, MA 02122, United States
# 970 Washington St, Boston, MA 02132, USA
# 971 101 Dale St, Roxbury, MA 02119, United States
# 972 1701 Washington St, Boston, MA 02118, United States
# 973 Washington St, DORCHESTR CTR, MA 02124, USA
# 974 235 Washington St, Boston, MA 02201, USA
# 975 4560 Washington St, Roslindale, MA 02131, United States
# 976 180 Shawmut Ave, Boston, MA 02118, United States
# 977 85 Seaport Blvd, Boston, MA 02210, United States
# 978 505 Congress St, Boston, MA 02210, United States
# 979 385 Chestnut Hill Ave, Boston, MA 02135, United States
# 980 1350 Columbia Rd, Boston, MA 02127, United States
# 981 75 Arlington St Floor 10, Boston, MA 02116, United States
# 982 47 West St, Boston, MA 02111, United States
# 983 9 Bronsdon St, Brighton, MA 02135, United States
# 984 53 Hartford St, Boston, MA 02125, United States
# 985 16 Ronald St, Boston, MA 02121, United States
# 986 Wayne St, Boston, MA 02121, USA
# 987 Wayne St & Blue Hill Avenue, Boston, MA 02121, USA
# 988 173 Columbia Rd #173, Dorchester, MA 02121, United States
# 989 1 Shandon Rd, Dorchester Center, MA 02124, United States
# 990
# 991 Hummingbird Ln, Boston, MA 02126, United States
# 992 Hummingbird Ln, Boston, MA 02126, United States
# 993 101 Arch St, Boston, MA 02110, United States
# 994 45 W Broadway, Boston, MA 02127, United States
# 995 54 Pleasant St, Boston, MA 02125, United States
# 996 110 Peterborough St, Boston, MA 02215, United States
# 997 258 W Newton St, Boston, MA 02116, USA
# 998 236 W 9th St, Boston, MA 02127, USA
# 999 1235 VFW Pkwy, West Roxbury, MA 02132, United States
# 1000 320 D St, Boston, MA 02127, United States
# 1001 66 Westland Ave # 205, Boston, MA 02115, United States
# 1002 1542 Columbus Ave, Roxbury, MA 02119, United States
# 1003 Westminster Ct, Boston, MA 02119, USA
# 1004 1158 Tremont St, Boston, MA 02120, United States
# 1005
# 1006 95 Humboldt Ave # A, Dorchester, MA 02121, United States
# 1007 1313 Washington St, Boston, MA 02118, United States
# 1008
# 1009 Willowwood St, Boston, MA 02124, USA
# 1010 Cheney St, Boston, MA 02121, United States
# 1011 Winslow St, Boston, MA 02119, USA
# 1012
# 1013
# 1014 6 Southbourne Road, 4208 Jamaica Plain 02130, United Kingdom
# 1015
# 1016 Woodledge St, Boston, MA 02125, USA
# 1017 Woodward Park St, Boston, MA 02125, USA
# 1018 Woodward Park St, Boston, MA 02125, USA
# 1019
# 1020 Worcester Square, Boston, MA 02118, USA
# 1021 120 Taunton St, Wrentham, MA 02093, United States
# 1022 404 W 2nd St, Boston, MA 02127, USA
# 1023
# 1024 St George St, Boston, MA 02118, USA
# 1025 558 Washington St, Boston, MA 02111, United States
# 1026 39 A St, Boston, MA 02127, United States
# 1027 39 A St, Boston, MA 02127, United States
# 1028 218 Adams St, Dorchester, MA 02122, United States
# 1029 710 Albany St C1, Boston, MA 02118, United States
# 1030 15 Algonquin St, Boston, MA 02124, United States
# 1031 131 Dale St, Boston, MA 02119, United States
# 1032 2P, Alvah Kittredge Park, Boston, MA 02119, United States
# 1033 Boston, MA 02136, United States
# 1034 125 Amory St, Boston, MA 02119, United States
# 1035 125 Amory St, Boston, MA 02119, United States
# 1036 120 Mt Pleasant Ave, Boston, MA 02119, USA
# 1037 380 Harrison Ave, Boston, MA 02118, United States
# 1038 27 Centre St, Boston, MA 02119, United States
# 1039 637 Washington St, Boston, MA 02124, United States
# 1040 9 Arlington St, Boston, MA 02116, United States
# 1041
# 1042 QRRR+FGV, Mandela Ave, Georgetown, Guyana
# 1043 35 W 2nd St, Boston, MA 02127, United States
# 1044 30 B St, South Boston, MA 02127, United States
# 1045 15 Banton St, Dorchester Center, MA 02124, United States
# 1046 35 Batchelder St, Boston, MA 02119, United States
# 1047 210 South St, Boston, MA 02111, United States
# 1048 331 Belgrade Ave, Boston, MA 02131, United States
# 1049 43 Freeport St, Boston, MA 02122, United States
# 1050 354-356 Bennington St, East Boston, MA 02128, United States
# 1051 121 Bennington St, Boston, MA 02128, United States
# 1052 917 Bennington St, Boston, MA 02128, United States
# 1053
# 1054 Blackinton St, Boston, MA 02128, USA
# 1055 286 Blue Hill Avenue, Roxbury, MA 02119, United States
# 1056 1480 Blue Hill Avenue, Boston, MA 02126, United States
# 1057 162 Boardman St, East Boston, MA 02128, United States
# 1058 430 William F McClellan Hwy, Boston, MA 02128, United States
# 1059 230 Bowdoin St, Dorchester, MA 02122, United States
# 1060 230 Bowdoin St, Dorchester, MA 02122, United States
# 1061 Bowdoin St, Boston, MA 02121, USA
# 1062 1330 Boylston St, Boston, MA 02215, United States
# 1063 Boylston St, Boston, MA 02116, USA
# 1064 Boylston St &, Tremont St, Boston, MA 02116, United States
# 1065 75 Braintree St, Allston, MA 02134, United States
# 1066 Breed St, Boston, MA 02128, USA
# 1067 70 S Bremen St, Boston, MA 02128, United States
# 1068 70 S Bremen St, Boston, MA 02128, United States
# 1069 89 Broad St, Boston, MA 02110, United States
# 1070 45 Brooks St, Boston, MA 02128, United States
# 1071 18 Haviland St, Boston, MA 02115, United States
# 1072 Burt St, Boston, MA 02124, USA
# 1073 43 Freeport St, Boston, MA 02122, United States
# 1074 355 Main St, Cambridge, MA 02142, United States
# 1075 334 Cambridge St, Boston, MA 02134, United States
# 1076 334 Cambridge St, Boston, MA 02134, United States
# 1077 43 Freeport St, Boston, MA 02122, United States
# 1078
# 1079 27 Centre St, Boston, MA 02119, United States
# 1080 225 Centre St, Roxbury, MA 02119, United States
# 1081 891 Centre St, Boston, MA 02130, United States
# 1082 12 Chamblet St, Boston, MA 02125, United States
# 1083 Chaucer St, Boston, MA 02128, USA
# 1084 115 Chauncy St #1740, Boston, MA 02111, United States
# 1085 1 Chelsea St, Charlestown, MA 02129, USA
# 1086 319 Chelsea St, Boston, MA 02128, United States
# 1087 319 Chelsea St, Boston, MA 02128, United States
# 1088 1 Chestnut Ave, Jamaica Plain, MA 02130, USA
# 1089 332 Chestnut Hill Ave, Brighton, MA 02135, United States
# 1090 Chipman St, Boston, MA 02124, USA
# 1091 43 Freeport St, Boston, MA 02122, United States
# 1092 62 Clifton St, Dorchester, MA 02125, United States
# 1093
# 1094 43 Freeport St, Boston, MA 02122, United States
# 1095 1 Coleman St, Boston, MA 02125, USA
# 1096 Coleman St, Boston, MA 02125, USA
# 1097 43 Freeport St, Boston, MA 02122, United States
# 1098 Colonial Ave, Boston, MA 02124, USA
# 1099 Boston, MA 02120, United States
# 1100 285 Columbus Ave, Boston, MA 02116, United States
# 1101 Boston, MA 02120, United States
# 1102 386 Commercial Street, Boston, MA 02109, United States
# 1103 1925 Commonwealth Ave, Boston, MA 02135, United States
# 1104 575 Commonwealth Ave, Boston, MA 02215, United States
# 1105 1144-1160 Commonwealth Ave, Boston, MA 02134, United States
# 1106 330 Congress St, Boston, MA 02210, United States
# 1107 Corman Rd, Boston, MA 02126, USA
# 1108 201 S Huntington Ave, Boston, MA 02130, United States
# 1109 86 Crawford St, Dorchester, MA 02121, United States
# 1110 627 Cummins Hwy, Mattapan, MA 02126, United States
# 1111 320 D St, Boston, MA 02127, United States
# 1112 320 D St, Boston, MA 02127, United States
# 1113 16 Dacia St, Dorchester, MA 02125, United States
# 1114 72 Dale St, Boston, MA 02119, United States
# 1115 647 Warren St #25, Dorchester, MA 02121, United States
# 1116 2235 Dorchester Ave, Boston, MA 02124, United States
# 1117 43 Freeport St, Boston, MA 02122, United States
# 1118 1420 Dorchester Ave, Dorchester, MA 02122, United States
# 1119 141 Dorchester Ave, Boston, MA 02127, United States
# 1120 39 Dorchester St, South Boston, MA 02127, United States
# 1121 39 Dorchester St, South Boston, MA 02127, United States
# 1122 Draper St, Boston, MA 02122, USA
# 1123 778 Dudley St, Dorchester, MA 02125, United States
# 1124 550 Dudley St, Roxbury, MA 02119, United States
# 1125 43 Freeport St, Boston, MA 02122, United States
# 1126 Dunreath St, Boston, MA 02119, USA
# 1127 370 E Eagle St, Boston, MA 02128, United States
# 1128 330 Congress St, Boston, MA 02210, United States
# 1129 850 Summer Street Suite 207, Boston, MA 02127, United States
# 1130 444 E 3rd St, South Boston, MA 02127, United States
# 1131 726 E Broadway, Boston, MA 02127, United States
# 1132 Boston, MA 02119, United States
# 1133 131 Seaport Blvd, Boston, MA 02210, United States
# 1134 850 Summer Street Suite 207, Boston, MA 02127, United States
# 1135 516 E 2nd St, Boston, MA 02127, United States
# 1136 Boston, MA 02118, United States
# 1137 444 E 3rd St, South Boston, MA 02127, United States
# 1138 1480 Blue Hill Avenue, Boston, MA 02126, United States
# 1139 31 Erie St, Boston, MA 02121, United States
# 1140 Elwyn Rd, Boston, MA 02124, USA
# 1141 647 Warren St #25, Dorchester, MA 02121, United States
# 1142 302 Eustis St, Boston, MA 02119, United States
# 1143 61 Eutaw St, Boston, MA 02118, United States
# 1144 37 Evans St, Dorchester, MA 02124, United States
# 1145 10 Everett St, Boston, MA 02128, United States
# 1146 Fairland St, Boston, MA 02119, USA
# 1147 150 Fairmount Ave, Hyde Park, MA 02136, United States
# 1148 Falcon St, Boston, MA 02128, USA
# 1149 120 Fisher Ave, Boston, MA 02120, United States
# 1150 22-98 Fort Ave, Boston, MA 02119, United States
# 1151 Fottler Rd, Boston, MA 02126, USA
# 1152
# 1153 Gladstone St, Boston, MA 02128, USA
# 1154 Glendon St, Boston, MA 02128, USA
# 1155 90 Glenway St, Boston, MA 02121, United States
# 1156 90 Glenway St, Boston, MA 02121, United States
# 1157 90 Glenway St, Boston, MA 02121, United States
# 1158 40 Gordon Ave, Hyde Park, MA 02136, United States
# 1159 150 Green St, Boston, MA 02130, United States
# 1160 Greenbrier St, Boston, MA 02124, USA
# 1161 Greenwich Park, Boston, MA 02118, USA
# 1162 120 H St, Boston, MA 02127, United States
# 1163 233 Hancock St, Dorchester, MA 02125, United States
# 1164 332 Hanover St, Boston, MA 02113, United States
# 1165 85 Harold St, Boston, MA 02119, United States
# 1166 345 Harrison Ave, Boston, MA 02118, United States
# 1167 700 Harrison Ave, Boston, MA 02118, United States
# 1168 345 Harrison Ave, Boston, MA 02118, United States
# 1169 55 Harvard St, Boston, MA 02124, United States
# 1170 2 Hawthorne Pl, Boston, MA 02114, United States
# 1171 9 Fulda St, Boston, MA 02119, United States
# 1172 768 Huntington Ave, Boston, MA 02115, United States
# 1173 Hemenway St, Boston, MA 02115, USA
# 1174 Hendry St, Boston, MA 02122, USA
# 1175 26 Hichborn St, Brighton, MA 02135, United States
# 1176 Highland St, Boston, MA 02119, USA
# 1177 1 Highland St, Roxbury, MA 02119, United States
# 1178 647 Warren St #25, Dorchester, MA 02121, United States
# 1179 55 Hollander St, Roxbury, MA 02119, United States
# 1180 Homes Ave, Boston, MA 02122, USA
# 1181 Hosmer St, Boston, MA 02126, USA
# 1182
# 1183 185 Howard Ave, Dorchester, MA 02125, United States
# 1184 72 Dale St, Boston, MA 02119, United States
# 1185 66 Hudson St, Boston, MA 02111, United States
# 1186 198 Humboldt Ave, Dorchester, MA 02121, United States
# 1187 202 Humboldt Ave, Boston, MA 02121, United States
# 1188 Humphreys Pl, Boston, MA 02125, USA
# 1189 201 S Huntington Ave, Boston, MA 02130, United States
# 1190 17 Blakeville St, Dorchester, MA 02121, United States
# 1191 1074 Hyde Park Ave, Hyde Park, MA 02136, United States
# 1192 1074 Hyde Park Ave, Hyde Park, MA 02136, United States
# 1193 Intervale St, Boston, MA 02121, USA
# 1194
# 1195 72 Dale St, Boston, MA 02119, United States
# 1196 71 Kingsdale St, Dorchester Center, MA 02124, United States
# 1197 77 L St, Boston, MA 02127, United States
# 1198 1480 Blue Hill Avenue, Boston, MA 02126, United States
# 1199 One Boston Place, #2600, Boston, MA 02108, United States
# 1200 647 Warren St #25, Dorchester, MA 02121, United States
# 1201 Leighton Rd, Boston, MA 02136, USA
# 1202 Leroy St, Boston, MA 02122, USA
# 1203 43 Freeport St, Boston, MA 02122, United States
# 1204 599 Lexington Ave, New York, NY 10022, United States
# 1205 1 Lexington St, Boston, MA 02128, USA
# 1206
# 1207 Leyden St, Boston, MA 02128, USA
# 1208 1 Lorne St, Boston, MA 02124, United States
# 1209 206 Magnolia St, Boston, MA 02121, United States
# 1210 Magnolia St, Boston, MA 02125, USA
# 1211 647 Warren St #25, Dorchester, MA 02121, United States
# 1212 40 Malvern St, Boston, MA 02134, United States
# 1213 Manor St, Boston, MA 02122, USA
# 1214 127 Marion St, Boston, MA 02128, United States
# 1215 127 Marion St, Boston, MA 02128, United States
# 1216 207 Market St, Brighton, MA 02135, United States
# 1217 207 Market St, Brighton, MA 02135, United States
# 1218 811 Massachusetts Ave, Boston, MA 02118, United States
# 1219 1258 Massachusetts Ave, Dorchester, MA 02125, United States
# 1220 666 Massachusetts Ave, Boston, MA 02118, United States
# 1221 Maverick St, Boston, MA 02128, USA
# 1222 Maverick St, Boston, MA 02128, USA
# 1223 131 Dale St, Boston, MA 02119, United States
# 1224 141 McBride St, Jamaica Plain, MA 02130, United States
# 1225 305 Medford St, Boston, MA 02129, United States
# 1226 680 Metropolitan Ave, Hyde Park, MA 02136, United States
# 1227 637 Washington St, Boston, MA 02124, United States
# 1228 91 Minden St, Jamaica Plain, MA 02130, United States
# 1229 91 Minden St, Jamaica Plain, MA 02130, United States
# 1230 9 Miner St, Boston, MA 02215, United States
# 1231 Msgr Patrick J Lydon Way, Boston, MA 02124, USA
# 1232 Morris St, Boston, MA 02128, USA
# 1233 647 Warren St #25, Dorchester, MA 02121, United States
# 1234 Mt Everett St, Boston, MA 02125, USA
# 1235 120 Mountfort St, Boston, MA 02215, United States
# 1236 28 Mt Pleasant Ave, Boston, MA 02119, United States
# 1237 28 Mt Pleasant Ave, Boston, MA 02119, United States
# 1238 must call for appointment, 39 Smith St, Boston, MA 02120, United States
# 1239 4 Murray Ave #1, Boston, MA 02119, USA
# 1240 15 N Beacon St, Allston, MA 02134, United States
# 1241 15 N Beacon St, Boston, MA 02134, United States
# 1242 15 N Beacon St, Allston, MA 02134, United States
# 1243 N Beacon St, Boston, MA 02134, USA
# 1244 43 Freeport St, Boston, MA 02122, United States
# 1245 320 Neponset Ave, Dorchester, MA 02122, United States
# 1246 Newbury St, Boston, MA 02115, USA
# 1247 101 Nightingale St, Boston, MA 02124, United States
# 1248 Norfolk St, DORCHESTR CTR, MA 02124, USA
# 1249 27 Centre St, Boston, MA 02119, United States
# 1250 35 Northampton St, Boston, MA 02118, United States
# 1251
# 1252 Norwell St, Boston, MA 02121, USA
# 1253 Oak St, Boston, MA 02111, USA
# 1254 200 Old Colony Ave, Boston, MA 02127, United States
# 1255 232 Old Colony Ave, Boston, MA 02127, United States
# 1256 150 Orleans St, Boston, MA 02128, United States
# 1257 Otisfield St, Boston, MA 02121, USA
# 1258
# 1259 231-235 Park Dr, Boston, MA 02215, United States
# 1260 50B Park St, Boston, MA 02122, United States
# 1261 124 Park St, Boston, MA 02122, United States
# 1262 27 Centre St, Boston, MA 02119, United States
# 1263 11 Parker Hill Ave, Boston, MA 02120, United States
# 1264 9 Peacevale Rd, Boston, MA 02124, United States
# 1265 109 Peterborough St, Boston, MA 02215, United States
# 1266 109 Peterborough St, Boston, MA 02215, United States
# 1267 200 Pier 4 Blvd., Boston, MA 02210, United States
# 1268 54 Pleasant St, Boston, MA 02125, United States
# 1269 161 Prescott St #500, Boston, MA 02128, United States
# 1270 320 Hanover St, Boston, MA 02113, United States
# 1271 Princeton St, Boston, MA 02128, USA
# 1272 223 1/2 Princeton St, Boston, MA 02128, USA
# 1273 43 Freeport St, Boston, MA 02122, United States
# 1274 196 Putnam St, Boston, MA 02128, United States
# 1275 Quincy St, Boston, MA 02125, USA
# 1276 43 Freeport St, Boston, MA 02122, United States
# 1277 1 Quincy St, Boston, MA 02121, USA
# 1278 Ridgewood St, Boston, MA 02122, USA
# 1279 Rill St, Boston, MA 02125, USA
# 1280 853 River St, Hyde Park, MA 02136, United States
# 1281 79 River St, Mattapan, MA 02126, United States
# 1282 79 River St, Mattapan, MA 02126, United States
# 1283 85 Robert St, Boston, MA 02131, United States
# 1284 must call for appointment, 39 Smith St, Boston, MA 02120, United States
# 1285 28 Rockwell St, Boston, MA 02124, United States
# 1286 72 Dale St, Boston, MA 02119, United States
# 1287 25 Ruggles St, Boston, MA 02119, United States
# 1288 154 Ruskindale Rd, Hyde Park, MA 02136, United States
# 1289 425-439 Rutherford Ave, Boston, MA 02129, United States
# 1290 1150 Saratoga St, Boston, MA 02128, United States
# 1291 1150 Saratoga St, Boston, MA 02128, United States
# 1292 125 Savin Hill Ave, Dorchester, MA 02124, United States
# 1293 must call for appointment, 39 Smith St, Boston, MA 02120, United States
# 1294 Schuyler St, Boston, MA 02121, USA
# 1295 122 Seaver St, Boston, MA 02121, United States
# 1296 98 Selden St, Dorchester, MA 02124, United States
# 1297 Selden St, DORCHESTR CTR, MA 02124, USA
# 1298 13 Shetland St, Boston, MA 02119, United States
# 1299 116 Huntington Ave, Boston, MA 02116, United States
# 1300 Southern Ave, Boston, MA 02124, USA
# 1301 Boston, MA 02215, United States
# 1302 Boston, MA 02124, United States
# 1303 116 Spring St, Boston, MA 02132, United States
# 1304 95 St Alphonsus St, Boston, MA 02120, United States
# 1305 St Andrew Rd, Boston, MA 02128, USA
# 1306 St Andrew Rd, Boston, MA 02128, USA
# 1307 647 Warren St #25, Dorchester, MA 02121, United States
# 1308 350 North St, Boston, MA 02113, United States
# 1309 Stonley Rd, Boston, MA 02130, USA
# 1310 17 Stoughton St, Dorchester, MA 02125, United States
# 1311 must call for appointment, 39 Smith St, Boston, MA 02120, United States
# 1312 164 Summit Ave, Providence, RI 02906, United States
# 1313 125 Sumner St, Boston, MA 02128, United States
# 1314
# 1315 Falmer, Brighton BN1 9RH, United Kingdom
# 1316 Sussex St, Boston, MA 02120, USA
# 1317 10 Taber St, Boston, MA 02119, United States
# 1318 17 Taft Hill Terrace, Boston, MA 02131, United States
# 1319 191 Talbot Ave, Boston, MA 02124, United States
# 1320 Talbot Ave, Boston, MA 02124, USA
# 1321 191 Talbot Ave, Boston, MA 02124, United States
# 1322 1480 Blue Hill Avenue, Boston, MA 02126, United States
# 1323 1485 Dorchester Ave, Dorchester, MA 02122, United States
# 1324 Tonawanda St, Boston, MA 02124, USA
# 1325 Topliff St, Boston, MA 02122, USA
# 1326 43 Freeport St, Boston, MA 02122, United States
# 1327 Boston, MA 02120, United States
# 1328 Boston, MA 02120, United States
# 1329 1457 Tremont St, Boston, MA 02120, United States
# 1330 111 Tremont St #109, Brighton, MA 02135, United States
# 1331 792 Truman Pkwy, Boston, MA 02136, United States
# 1332 Union Ave, Boston, MA 02130, USA
# 1333
# 1334 14 W Broadway, Boston, MA 02127, United States
# 1335
# 1336 252 W Newton St, Boston, MA 02116, United States
# 1337 W Park St, Boston, MA 02124, USA
# 1338 340 W 2nd St, Boston, MA 02127, United States
# 1339 340 W 2nd St, Boston, MA 02127, United States
# 1340 Walk Hill St, Boston, MA 02126, USA
# 1341 11 Walley St, Boston, MA 02128, United States
# 1342 27 Wareham St, Boston, MA 02118, United States
# 1343 529 Chestnut St, Ashland, MA 01721, United States
# 1344 1 Warren St, Boston, MA 02119, USA
# 1345
# 1346 1387 Washington St, Boston, MA 02118, United States
# 1347 Washington St, Boston, MA 02119, USA
# 1348
# 1349 1387 Washington St, Boston, MA 02118, United States
# 1350 4185 Washington St, Roslindale, MA 02131, United States
# 1351 Washington St, Boston, MA 02121, USA
# 1352 194 Callender St, Dorchester Center, MA 02124, United States
# 1353
# 1354 1145 Washington St, Boston, MA 02118, United States
# 1355 72 Dale St, Boston, MA 02119, United States
# 1356 Wayland St, Boston, MA 02125, USA
# 1357 1 Wellesley Park, Boston, MA 02124, USA
# 1358
# 1359 Wentworth St, Boston, MA 02124, USA
# 1360 W Seventh St, Boston, MA 02127, USA
# 1361 51 W Seventh St, Boston, MA 02127, United States
# 1362 14 W Broadway, Boston, MA 02127, United States
# 1363 340 W 2nd St, Boston, MA 02127, United States
# 1364 66 Walnut Park, Roxbury, MA 02119, United States
# 1365 446 Western Ave, Boston, MA 02135, United States
# 1366 16 Westland Ave, Boston, MA 02115, United States
# 1367
# 1368
# 1369 Westmore Rd, Boston, MA 02126, USA
# 1370 86 Wheatland Ave, Boston, MA 02124, United States
# 1371 43 Freeport St, Boston, MA 02122, United States
# 1372 131 Dale St, Boston, MA 02119, United States
# 1373 15 Bismarck St, Mattapan, MA 02126, United States
# 1374
# 1375 72 Dale St, Boston, MA 02119, United States
# 1376 Woodrow Ave, Boston, MA 02124, USA
# 1377 131 Dale St, Boston, MA 02119, United States
# 1378 Woodward St, Boston, MA 02127, USA
# 1379 66 Wordsworth St, East Boston, MA 02128, United States
# 1380 95 G St, Boston, MA 02127, United States
# 1381 131 Zeigler St, Boston, MA 02119, United States
# 1382 39 A St, Boston, MA 02127, United States
# 1383 320 D St, Boston, MA 02127, United States
# 1384 388 Blue Hill Avenue, Boston, MA 02121, United States
# 1385 260 Bowdoin St, Dorchester, MA 02122, United States
# 1386
# 1387 Chelsea St, Boston, MA 02128, USA
# 1388 Coleman St, Boston, MA 02125, USA
# 1389 926 Cummins Hwy, Mattapan, MA 02126, United States
# 1390 Dorchester Ave, DORCHESTR CTR, MA 02124, USA
# 1391 141 Dorchester Ave, Boston, MA 02127, United States
# 1392 20 Eustis St, Roxbury, MA 02119, United States
# 1393 Everett St, Boston, MA 02128, USA
# 1394 Gladstone St, Boston, MA 02128, USA
# 1395 354 Harrison Ave, Boston, MA 02118, United States
# 1396 206 Magnolia St, Boston, MA 02121, United States
# 1397 658 E 8th St, Boston, MA 02127, United States
# 1398 1 Lexington St, Boston, MA 02128, USA
# 1399 206 Magnolia St, Boston, MA 02121, United States
# 1400 131 Lexington St, Boston, MA 02128, United States
# 1401 241 Market St, Brighton, MA 02135, United States
# 1402 Maverick St, Boston, MA 02128, USA
# 1403 Norwood, MA 02062, United States
# 1404 9 Peacevale Rd, Boston, MA 02124, United States
# 1405 60 Old Colony Ave, Boston, MA 02127, United States
# 1406 885 River St, Boston, MA 02136, United States
# 1407 Saratoga St, Boston, MA 02128, USA
# 1408 185 Talbot Ave, Dorchester, MA 02124, United States
# 1409 1480-1482 Tremont St, Boston, MA 02120, United States
# 1410 45 W Broadway, Boston, MA 02127, United States
# 1411 3200 Washington St, Jamaica Plain, MA 02130, United States
# 1412 Wentworth St, Boston, MA 02124, USA
# 1413 45 W Broadway, Boston, MA 02127, United States
# 1414 x x x, 119 Braintree St UNIT 403, Allston, MA 02134, United States
# 1415 10 Corporate Dr, Burlington, MA 01803, United States
# 1416 x x x, 119 Braintree St UNIT 403, Allston, MA 02134, United States
# 1417
# 1418 x x x, 119 Braintree St UNIT 403, Allston, MA 02134, United States
# 1419
# 1420 x x x, 119 Braintree St UNIT 403, Allston, MA 02134, United States
# 1421 x x x, 119 Braintree St UNIT 403, Allston, MA 02134, United States
# 1422 10 Corporate Dr, Burlington, MA 01803, United States
# 1423
# 1424
# 1425 Beacon St, Boston, MA 02215, USA
# 1426
# 1427
# 1428
# 1429
# 1430 Saratoga St, Boston, MA 02128, USA
# 1431
# 1432 W Broadway, Boston, MA 02127, USA
# 1433 388 Blue Hill Avenue, Boston, MA 02121, United States
# 1434
# 1435
# 1436 6 W Broadway, Boston, MA 02127, United States
# 1437 1140 Washington St, Dorchester Center, MA 02124, United States
# 1438 6 W Broadway, Boston, MA 02127, United States
# 1439 388 Blue Hill Avenue, Boston, MA 02121, United States
# 1440 491 Blue Hill Avenue, Boston, MA 02121, United States
# 1441 1785 Columbus Ave #500, Roxbury, MA 02119, United States
# 1442 40 Berkeley St, Boston, MA 02116, United States
# 1443 140 Clarendon St, Boston, MA 02116, United States
# 1444 1313 Washington St, Boston, MA 02118, United States

# %% [markdown]
# ### 2.Seperate Street from Address

# %%
# get street info from address 
def get_street(s):
    street = ''
    # split based on empty space
    ss = s.split(' ')
    for i in ss:
        # set length greater than 2 to remove ST,SE
        if len(i)>2:
            street = i
    return street.lower()
# save street info to street column in boston data frame
df_boston['street'] = df_boston['FULL_STR'].apply(get_street)
df_boston['street']
# Out:
# 0         trenton
# 1         trenton
# 2           eagle
# 3           eagle
# 4           eagle
#            ...
# 98686     brayton
# 98687    rockland
# 98688    rushmore
# 98689     linwood
# 98690        park
# Name: street, Length: 98691, dtype: object

# %% [markdown]
# ### 3. Seperate Each field in Street

# %%
def deal_address(s):
    # remove non word character such as , : '' etc
    s = re.sub("\W", " ", str(s))
    # split on empty space
    return s.lower().split(' ')
# save new seperated address to address1 column in income data frame
df_income['address1'] = df_income['address'].apply(deal_address)
df_income['address1']
# Out:
# 0       [100, shawmut, ave, , boston, , ma, 02118, , u...
# 1       [1592, columbus, ave, , roxbury, , ma, 02119, ...
# 2       [2926, washington, st, , roxbury, , ma, 02119,...
# 3                                                   [nan]
# 4                                                   [nan]
#                               ...
# 1440    [491, blue, hill, avenue, , boston, , ma, 0212...
# 1441    [1785, columbus, ave, , 500, , roxbury, , ma, ...
# 1442    [40, berkeley, st, , boston, , ma, 02116, , un...
# 1443    [140, clarendon, st, , boston, , ma, 02116, , ...
# 1444    [1313, washington, st, , boston, , ma, 02118, ...
# Name: address1, Length: 1445, dtype: object

# %% [markdown]
# ### 4. Check if Address in Income Restrcited Dataset is affordable in Boston Assessor Dataset

# %%
save_res = []
def match_address(s):
    # flag = 0 meaning income restricted address is not in boston assessor dataset flag = 1 vice versa 
    flag = 0
    for j in range(len(df_income)):
        # check if street info is in each field of address in address1 which is from income restricted dataset
        if s in df_income['address1'][j]:
            # save the address to the list
            save_res.append(list(df_income.loc[j]))
            flag = 1
            break
    if flag == 0:
        # save address with nan
        save_res.append([np.nan]*len(df_income.columns))
    # print(len(save_res))
# apply match_address function to each row in street column
df_boston['street'].apply(match_address)
# Out:
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
#          ...
# 98686    None
# 98687    None
# 98688    None
# 98689    None
# 98690    None
# Name: street, Length: 98691, dtype: object

# %%
# save the new result dataframe 
df_res = pd.DataFrame(save_res,columns=df_income.columns)
# df_res[:3]

# %% [markdown]
# ### 5.Combine New Dataset with Boston Assessor Dataset

# %%
# add df_res columns data to boston assessor dataframe
df_boston[list(df_income.columns)] = df_res
df_boston.to_csv('data/Boston Assessor added Income Restricted.csv',index=None)

# %% [markdown]
# ### 6.Tranform Fields to Appropriate Format

# %%
# transform zip code to string 
def deal_zip(s):
    try:
        # return string format of zip code
        return str(int(s))
    except:
        return ''
df_boston['ZIP'] = df_boston['ZIP'].apply(deal_zip)
df_boston['ZIP']
# Out:
# 0        2128
# 1        2128
# 2        2128
# 3        2128
# 4        2128
#          ...
# 98686    2135
# 98687    2132
# 98688    2135
# 98689    2119
# 98690    2130
# Name: ZIP, Length: 98691, dtype: object

# %%
# transform city to lower case
def deal_city(s):
    return str(s).lower()
df_boston['CITY'] = df_boston['CITY'].apply(deal_city)

# %% [markdown]
# ### 7. Seperate Affordable and Non Affordable Housing

# %%
# affordable housing
df_boston_is = df_boston.dropna(subset=["Project Name"])
# non affordable housing 
df_boston_not = df_boston[df_boston["Project Name"].isnull()]

# %% [markdown]
# # Step 1

# %% [markdown]
# ## 1.a Number of Units

# %%
df_boston_not_units_sum = df_boston_not["UNITS"].sum()
df_boston_not_units_sum
# Out:
# 19364

# %% [markdown]
# ## 1.b Geographic Distribution by Zip Code

# %%
# group by zip code for different PROP_ID
df_boston_not_zip = df_boston_not.groupby(["ZIP"])['PROP_ID'].count().reset_index().sort_values(by="PROP_ID", ascending=False)
plt.figure(figsize=(8, 5))
plt.bar(df_boston_not_zip['ZIP'][:15], df_boston_not_zip['PROP_ID'][:15])
plt.ylabel("count", fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ## 1.c Demographic profile of census block group (majority race, ethnicity, income)

# %%
df_neighborhood = pd.read_csv('data/boston-neighborhood-data.csv')
# select all the race columns
df_neighborhood1 = df_neighborhood[['field concept', 'Total:', 'White alone',
       'Black or African American alone', 'Hispanic or Latino',
       'Asian, Native Hawaiian and Pacific Islander alone, all ages',
       'Other Races or Multiple Races,  all ages']]
# rename field concept to CITY 
df_neighborhood1.rename(columns={'field concept':'CITY'}, inplace = True)
df_neighborhood1['CITY'] = df_neighborhood1['CITY'].apply(deal_city)
# merge neighboorhood with non affordable dataframe
df_neighborhood2 = pd.merge(df_boston_not, df_neighborhood1, on=['CITY'])

# remove duplicate city
df_neighborhood2.drop_duplicates(subset=["CITY"],keep='first', inplace=True)
df_neighborhood2.index = range(len(df_neighborhood2))
df_neighborhood2
# Out:
#     Unnamed: 0     PROP_ID            LOC_ID  BLDG_VAL  LAND_VAL  OTHER_VAL  \
# 0            1   100213000  F_783144_2964233         0         0          0
# 1         4372   200626000  F_773799_2963258   1029100    222700          0
# 2        29205   600986000  F_777804_2947544         0     94300          0
# 3        35942   800773000  F_771292_2944332    178608     88601      11282
# 4        35976   703977000  F_774955_2941548    411800    184300          0
# 5        40555  1001585000  F_760333_2944099       200  67350100          0
# 6        51806  1404163000  F_766664_2927274         0    152200          0
# 7        56135  1405197000  F_765572_2931959    269400    801400     225000
# 8        65562  1801416000  F_763535_2920691    280400    127100          0
# 9        81509  2001840000  F_752361_2927191    453100    301100          0
# 10       92800  2101362000  F_752743_2953986    346400    187500          0
# 11       92810  2101376000  F_752243_2953895         0     44200          0
#
#     TOTAL_VAL    FY  LOT_SIZE     LS_DATE  ...  Includes Senior Units?  \
# 0           0  2020      0.00  19920928.0  ...                     NaN
# 1     1251800  2020      0.02  20170428.0  ...                     NaN
# 2       94300  2020      0.06  20120625.0  ...                     NaN
# 3      278491  2020      2.03  20111027.0  ...                     NaN
# 4      596100  2020      0.00  19910102.0  ...                     NaN
# 5    67350300  2020     53.23  20180101.0  ...                     NaN
# 6      152200  2020      0.14  20030204.0  ...                     NaN
# 7     1295800  2020      2.20  19870101.0  ...                     NaN
# 8      407500  2020      0.00  19870101.0  ...                     NaN
# 9      754200  2020      0.00  20130604.0  ...                     NaN
# 10     533900  2020      0.00  20040621.0  ...                     NaN
# 11      44200  2020      0.00  19870101.0  ...                     NaN
#
#     Section 8 address address1  Total: White alone  \
# 0         NaN     NaN      NaN   43066       15760
# 1         NaN     NaN      NaN   19120       13626
# 2         NaN     NaN      NaN   37917       29139
# 3         NaN     NaN      NaN   54905        7182
# 4         NaN     NaN      NaN  122191       27411
# 5         NaN     NaN      NaN   41012       22032
# 6         NaN     NaN      NaN   23834        1489
# 7         NaN     NaN      NaN   29386       13428
# 8         NaN     NaN      NaN   33009        7449
# 9         NaN     NaN      NaN   31561       20918
# 10        NaN     NaN      NaN   28621       14634
# 11        NaN     NaN      NaN   48330       30596
#
#    Black or African American alone Hispanic or Latino  \
# 0                             1403              21700
# 1                              990               2075
# 2                             1529               3887
# 3                            22796              16728
# 4                            42714              25285
# 5                             4686               8921
# 6                            16277               4079
# 7                             6045               7373
# 8                            15171               7901
# 9                             3312               3567
# 10                            1451               3657
# 11                            2289               4978
#
#    Asian, Native Hawaiian and Pacific Islander alone, all ages  \
# 0                                                1932
# 1                                                1650
# 2                                                2077
# 3                                                3277
# 4                                               13360
# 5                                                2985
# 6                                                 490
# 7                                                1018
# 8                                                 677
# 9                                                2451
# 10                                               7173
# 11                                               7801
#
#    Other Races or Multiple Races,  all ages
# 0                                      2271
# 1                                       779
# 2                                      1285
# 3                                      4922
# 4                                     13421
# 5                                      2388
# 6                                      1499
# 7                                      1522
# 8                                      1811
# 9                                      1313
# 10                                     1706
# 11                                     2666
#
# [12 rows x 75 columns]

# %%
labels = ['White alone','Black or African American alone', 'Hispanic or Latino',
     'Asian, Native Hawaiian and Pacific Islander alone, all ages',
       'Other Races or Multiple Races,  all ages']
y = []
for col in labels:
    y.append(df_neighborhood2[col].sum())

# %%
# pie chart 
plt.figure(figsize=(8, 5))
plt.pie(y,labels=labels,autopct='%.2f%%')
plt.show()

# %% [markdown]
# # Step 2

# %% [markdown]
# ## 2.a Number of Units

# %%
df_neighborhood2 = pd.merge(df_boston_is, df_neighborhood1, on=['CITY'])
df_neighborhood2.drop_duplicates(subset=["CITY"],keep='first', inplace=True)
df_neighborhood2.index = range(len(df_neighborhood2))
labels = ['White alone','Black or African American alone', 'Hispanic or Latino',
     'Asian, Native Hawaiian and Pacific Islander alone, all ages',
       'Other Races or Multiple Races,  all ages']
y = []
for col in labels:
    y.append(df_neighborhood2[col].sum())
plt.figure(figsize=(8, 5))
plt.pie(y,labels=labels,autopct='%.2f%%')
plt.show()

# %% [markdown]
# ## Landlord Case

# %% [markdown]
# ### 2a Number of Units

# %%
len(df_boston_is)
# OWNER1 column is the name of the landlords, we group by OWNER1 for different UNITS
df_boston_is_OWNER1 = df_boston_is.groupby(["OWNER1"])['UNITS'].sum().reset_index().sort_values(by="UNITS", ascending=False)
df_boston_is_OWNER1.index = range(len(df_boston_is_OWNER1))
df_boston_is_OWNER1
# Out:
#                                   OWNER1  UNITS
# 0                 MILLENNIUM TOWER TRUST    442
# 1               HARBOR TOWERS 1 CONDO TR    308
# 2                       SOUTH END 10 LLC    273
# 3      MILLENIUM AVERY CONDOMINIUM TRUST    256
# 4                ONE CHARLES CONDOMINIUM    233
# ...                                  ...    ...
# 32487                  FRANCISCO OSCAR O      0
# 32488                  FRANCISCO GREGORY      0
# 32489                  FRANCISCO ARCADIO      0
# 32490                  FRANCISCO ANTONIO      0
# 32491                        ZYTO AURORE      0
#
# [32492 rows x 2 columns]

# %%
plt.figure(figsize=(8, 5))
# show first 20 landlord distribution
plt.bar(df_boston_is_OWNER1['OWNER1'][:20], df_boston_is_OWNER1['UNITS'][:20])
plt.ylabel("UNITS", fontsize=20)
plt.xticks(fontsize=10,rotation=90)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ### 2b Geographic Distribution by Zip Code

# %%
# group by zip code and landlord for different PROP_ID 
df_boston_is_zip_owwer = df_boston_not.groupby(["ZIP","OWNER1"])['PROP_ID'].count().reset_index().sort_values(by="PROP_ID", ascending=False)
df_boston_is_zip_owwer.rename(columns={'PROP_ID':'count'}, inplace = True)
df_boston_is_zip_owwer.index = range(len(df_boston_is_zip_owwer))
df_boston_is_zip_owwer
# Out:
#         ZIP              OWNER1  count
# 0      2132      CITY OF BOSTON    172
# 1      2126      CITY OF BOSTON    157
# 2      2136      CITY OF BOSTON    100
# 3      2119      CITY OF BOSTON     82
# 4      2131      CITY OF BOSTON     67
# ...     ...                 ...    ...
# 49712  2126  BROWN JAMES S ETAL      1
# 49713  2126  BROWN JAMES T ETAL      1
# 49714  2126   BROWN JOHN H ETAL      1
# 49715  2126       BROWN JULIA M      1
# 49716  2467        ZIDON ISRAEL      1
#
# [49717 rows x 3 columns]

# %%
# plot number of affordable housing in different zip code
plt.figure(figsize=(8, 5))
plt.bar(df_boston_is_zip_owwer['ZIP'][:15], df_boston_is_zip_owwer['count'][:15])
plt.ylabel("count", fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ## Housing Case

# %% [markdown]
# ### 2a Number of Units

# %%
# group by address of the leasing 
df_boston_is_OWN_ADDR = df_boston_is.groupby(["address"])['UNITS'].count().reset_index().sort_values(by="UNITS", ascending=False)
df_boston_is_OWN_ADDR.index = range(len(df_boston_is_OWN_ADDR))
df_boston_is_OWN_ADDR
# Out:
#                                                address  UNITS
# 0    380 Bunker Hill St, Charlestown, MA 02129, Uni...   1884
# 1    2926 Washington St, Roxbury, MA 02119, United ...   1531
# 2     100 Shawmut Ave, Boston, MA 02118, United States   1526
# 3    1344 Hyde Park Ave, Hyde Park, MA 02136, Unite...   1158
# 4    445 Adams St, Dorchester, MA 02122, United States   1111
# ..                                                 ...    ...
# 417  1 Westinghouse Plaza Building C, Hyde Park, MA...      1
# 418       3 Hazel St, Waltham, MA 02451, United States      1
# 419       1 Nassau St, Boston, MA 02111, United States      1
# 420  75 Flaherty Way, South Boston, MA 02127, Unite...      1
# 421  55 Fruit St # 410, Boston, MA 02114, United St...      1
#
# [422 rows x 2 columns]

# %%
# get latitude and longitutde for housings
import requests
import urllib.parse
df = df_boston_is_OWN_ADDR[:1000]
save_lat = []
save_lon = []
for i in range(len(df)):
    
    try:
        city = df['address'][i]
        country = "USA"
        url = "https://nominatim.openstreetmap.org/?addressdetails=1&q=" + city + "+" + country +"&format=json&limit=1"

        response = requests.get(url).json()
        save_lat.append(response[0]["lat"])
        save_lon.append(response[0]["lon"])
        print(i,response[0]["lat"],response[0]["lon"])
    except:
        save_lat.append('')
        save_lon.append('')
# Out:
# 55 33.564526 -86.786198
# 88 42.2376391 -71.012255
# 97 42.6294489 -83.3052014
# 110 40.7131834 -74.003942

# %%
df['lat'] = save_lat
df['lon'] = save_lon
df.to_csv('data/lat.csv',index=None)

# %%
plt.figure(figsize=(8, 5))
plt.bar(df_boston_is_OWN_ADDR['address'][:20], df_boston_is_OWN_ADDR['UNITS'][:20])
plt.ylabel("UNITS", fontsize=20)
plt.xticks(fontsize=10,rotation=90)
plt.yticks(fontsize=10)
plt.show()

# %%
import folium
import webbrowser
import numpy as np
from folium.plugins import HeatMap


df = pd.read_csv('data/lat.csv')
# Number of data obtained
num = df.shape[0]
# Get Latitude
lat = np.array(df["lat"][0:num])
# Get Longitude
lon = np.array(df["lon"][0:num])
# Get price and convert it to numpy floating point
price = np.array(df["UNITS"][0:num], dtype=float)
# Make data in the form of [lats, lons, price]
data1 = [[lat[i], lon[i], price[i]] for i in range(num) if str(lat[i])!='nan']
# Draw a Map with the center longitude and latitude [32, 120], and the starting zoom degree is 10 times
map_osm = folium.Map(location=[42.36047281889217, -71.06208556951843], zoom_start=10)
# Add the thermodynamic diagram to the previously established map
HeatMap(data1).add_to(map_osm)

file_path = r"data/ADDR.html"
# Save as html file
map_osm.save(file_path)

# %%
map_osm = folium.Map(location=[42.36047281889217, -71.06208556951843], zoom_start=10)
# Define colors for five clusters
rainbow = ['#8000ff', '#00b5eb', '#80ffb4', '#ffb360', '#ff0000']

for i in range(len(df)):
    if str(df['lat'][i])!='nan':
        folium.Marker([df["lat"][i], df["lon"][i]], color='#8000ff').add_to(map_osm)

file_path = r"data/ADDR CircleMarker.html"
# Save as html file
map_osm.save(file_path)

# %% [markdown]
# ### 2b Geographic Distribution by Zip Code

# %%
# group by zip code and address for different PROP_ID
df_boston_is_zip_OWN_ADDR = df_boston_is.groupby(["ZIP","address"])['PROP_ID'].count().reset_index().sort_values(by="PROP_ID", ascending=False)
df_boston_is_zip_OWN_ADDR.rename(columns={'PROP_ID':'count'}, inplace = True)
df_boston_is_zip_OWN_ADDR.index = range(len(df_boston_is_zip_OWN_ADDR))
df_boston_is_zip_OWN_ADDR
# Out:
#       ZIP                                            address  count
# 0    2127   100 Shawmut Ave, Boston, MA 02118, United States   1198
# 1    2128                    Saratoga St, Massachusetts, USA    528
# 2    2128  78 Bennington St, Boston, MA 02128, United States    422
# 3    2132  289 Centre St, Dorchester, MA 02122, United St...    417
# 4    2127     50 W Broadway, Boston, MA 02127, United States    400
# ..    ...                                                ...    ...
# 976  2127  75 Flaherty Way, South Boston, MA 02127, Unite...      1
# 977  2127                   Church St, Boston, MA 02122, USA      1
# 978  2127               Spencer House, Boston, MA 02119, USA      1
# 979  2129      10 Temple Pl, Boston, MA 02111, United States      1
# 980  2467     645 Beacon St, Boston, MA 02215, United States      1
#
# [981 rows x 3 columns]

# %%
# plot number of affordable housing in different zip code
plt.figure(figsize=(8, 5))
plt.bar(df_boston_is_zip_OWN_ADDR['ZIP'][:15], df_boston_is_zip_OWN_ADDR['count'][:15])
plt.ylabel("count", fontsize=20)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# # Step 3

# %%
citys = list(set(df_boston['CITY']))
# city
save_lat = []
save_lon = []
# get each city's latitude and longitude
for city in citys:
    
    try:
        country = "USA"
        url = "https://nominatim.openstreetmap.org/?addressdetails=1&q=" + city + "+" + country +"&format=json&limit=1"

        response = requests.get(url).json()
        save_lat.append(response[0]["lat"])
        save_lon.append(response[0]["lon"])
        print(city,response[0]["lat"],response[0]["lon"])
    except:
        
        save_lat.append('')
        save_lon.append('')
df_city = pd.DataFrame()
df_city['CITY'] = citys
df_city['lat'] = save_lat
df_city['lon'] = save_lon
df_city.to_csv('data/city_lat.csv',index=None)
# Out:
# dedham 41.9063152 -94.8222082
# west roxbury 42.2792649 -71.1494972
# roxbury crossing 42.3312546 -71.0955776
# boston 42.3554334 -71.060511
# hyde park 41.7944464 -87.5939244
# mattapan 42.2723208 -71.0869953
# brookline 42.3317642 -71.1211635
# east boston 42.3750973 -71.0392173
# charlestown 43.2387 -72.424622
# chestnut hill 42.3306529 -71.1661647
# south boston 42.3334312 -71.0494949
# brighton 39.983721 -104.8110775
# jamaica plain 42.3116046 -71.1143838
# readville 42.2403766 -71.1369964
# dorchester 38.3930694 -76.0995677
# roslindale 42.2912093 -71.1244966
# allston 42.3555375 -71.1327494
# roxbury 41.5568282 -73.3088922

# %% [markdown]
# ## Affordable Housing Case

# %%
df_boston_is_city = df_boston_is.groupby(["CITY"])['PROP_ID'].count().reset_index().sort_values(by="PROP_ID", ascending=False)
df_boston_is_city.index = range(len(df_boston_is_city))
df_boston_is_city.rename(columns={'PROP_ID':'count'}, inplace = True)
df_boston_is_city
# Out:
#                 CITY  count
# 0         dorchester   9513
# 1             boston   6341
# 2        east boston   4536
# 3          hyde park   3040
# 4       south boston   2945
# 5            roxbury   2578
# 6      jamaica plain   2152
# 7       west roxbury   2015
# 8         roslindale   1994
# 9        charlestown   1656
# 10          brighton   1431
# 11          mattapan   1366
# 12           allston    886
# 13  roxbury crossing    705
# 14     chestnut hill     22

# %%
df = pd.read_csv('data/city_lat.csv')
df_boston_is_city_lat  = pd.merge(df_boston_is_city, df, on=['CITY'])
# Number of data obtained
num = df_boston_is_city_lat.shape[0]
# Get Latitude
lat = np.array(df_boston_is_city_lat["lat"][0:num])
# Get Longitude
lon = np.array(df_boston_is_city_lat["lon"][0:num])
# Get price and convert it to numpy floating point
price = np.array(df_boston_is_city_lat["count"][0:num], dtype=float)
# Make data in the form of [lats, lons, price]
data1 = [[lat[i], lon[i], price[i]] for i in range(num) if str(lat[i])!='nan']
# Draw a Map with the center longitude and latitude [32, 120], and the starting zoom degree is 10 times
map_osm = folium.Map(location=[42.36047281889217, -71.06208556951843], zoom_start=10)
# Add the thermodynamic diagram to the previously established map
HeatMap(data1).add_to(map_osm)
 
file_path = r"data/Affordable Housing Geographic Distribution bt City.html"
# Save as html file
map_osm.save(file_path)

# %% [markdown]
# ## Non Affordable Housing Case

# %%
df_boston_not_city = df_boston_not.groupby(["CITY"])['PROP_ID'].count().reset_index().sort_values(by="PROP_ID", ascending=False)
df_boston_not_city.index = range(len(df_boston_not_city))
df_boston_not_city.rename(columns={'PROP_ID':'count'}, inplace = True)
df_boston_not_city
# Out:
#                 CITY  count
# 0         dorchester  13283
# 1       west roxbury   7539
# 2          hyde park   5092
# 3         roslindale   4965
# 4             boston   4271
# 5      jamaica plain   4231
# 6           brighton   3787
# 7       south boston   3425
# 8           mattapan   3111
# 9            roxbury   2236
# 10       east boston   1987
# 11       charlestown   1414
# 12           allston   1330
# 13  roxbury crossing    657
# 14     chestnut hill    154
# 15         brookline     21
# 16            dedham      7
# 17         readville      1

# %%
df = pd.read_csv('data/city_lat.csv')
df_boston_not_city_lat  = pd.merge(df_boston_not_city, df, on=['CITY'])
# Number of data obtained
num = df_boston_not_city_lat.shape[0]
# Get Latitude
lat = np.array(df_boston_not_city_lat["lat"][0:num])
# Get Longitude
lon = np.array(df_boston_not_city_lat["lon"][0:num])
# Get price and convert it to numpy floating point
price = np.array(df_boston_not_city_lat["count"][0:num], dtype=float)
# Make data in the form of [lats, lons, price]
data1 = [[lat[i], lon[i], price[i]] for i in range(num) if str(lat[i])!='nan']
# Draw a Map with the center longitude and latitude [32, 120], and the starting zoom degree is 10 times
map_osm = folium.Map(location=[42.36047281889217, -71.06208556951843], zoom_start=10)
# Add the thermodynamic diagram to the previously established map
HeatMap(data1).add_to(map_osm)
 
file_path = r"data/Nonaffordable Housing Geographic Distribution by City.html"
# Save as html file
map_osm.save(file_path)

# %% [markdown]
# # Step 4

# %%
# set correct use code for housing
residential_code = [i for i in range(101,111)]
apartment_code = [i for i in range(111,133)]
apartment_code.extend([202,211])
residential_code.extend(apartment_code)

# %%
# find all apartment and residential property in dataframe
df_boston_small = df_boston[df_boston.apply(lambda x: x['USE_CODE'] in residential_code, axis=1)]
# calculate the proportion
print(round(len(df_boston_small)/ len(df_boston), 4))
# Out:
# 0.7591

# %%
# drop non affordable housing to get addordable housing 
df_boston_small_affordable = df_boston_small.dropna(subset=["Project Name"])
# affordable housing size / all the aprtment and residential property
print(round(len(df_boston_small_affordable)/ len(df_boston_small), 4))
# Out:
# 0.3621
