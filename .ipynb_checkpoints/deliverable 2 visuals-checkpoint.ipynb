# %%
import pandas as pd

# %%
master = pd.read_csv('master_with_neighborhood_for_census.csv')

# %%
neighborhood = pd.read_csv('boston_neighborhood.csv')

# %%
neighborhood.head()
# Out:
#             nbhd P0020001     P0020005                         P0020006  \
# 0  field concept   Total:  White alone  Black or African American alone
# 1        Allston    28621        14634                             1451
# 2       Back Bay    19588        14056                              718
# 3    Beacon Hill     9336         7521                              252
# 4       Brighton    48330        30596                             2289
#
#              P0020002                                           P002aapi  \
# 0  Hispanic or Latino  Asian, Native Hawaiian and Pacific Islander al...
# 1                3657                                               7173
# 2                1326                                               2604
# 3                 537                                                630
# 4                4978                                               7801
#
#                                  P002others P0040001     P0040005  \
# 0  Other Races or Multiple Races,  all ages   Total:  White alone
# 1                                      1706    26668        14022
# 2                                       884    18374        13296
# 3                                       396     8603         6980
# 4                                      2666    44129        28706
#
#                           P0040006  ...  \
# 0  Black or African American alone  ...
# 1                             1294  ...
# 2                              669  ...
# 3                              231  ...
# 4                             1966  ...
#
#                                         P0050005  \
# 0  Nursing facilities/Skilled-nursing facilities
# 1                                             26
# 2                                            269
# 3                                              0
# 4                                            240
#
#                          P0050006                          P0050007  \
# 0  Other institutional facilities  Noninstitutionalized population:
# 1                               0                              3364
# 2                               0                              1701
# 3                               0                                33
# 4                              56                              3713
#
#                              P0050008           P0050009  \
# 0  College/University student housing  Military quarters
# 1                                3214                  0
# 2                                1578                  0
# 3                                   0                  0
# 4                                3493                  0
#
#                             P0050010 H0010001  H0010002 H0010003  \
# 0  Other noninstitutional facilities   Total:  Occupied   Vacant
# 1                                150    12527     11740      787
# 2                                123    12373     10788     1585
# 3                                 33     6037      5485      552
# 4                                220    21874     20822     1052
#
#            hhsize
# 0  household size
# 1     2.149148211
# 2     1.633110864
# 3     1.696080219
# 4       2.1279416
#
# [5 rows x 34 columns]

# %%
#df.groupby("A").agg(
#    b_min=pd.NamedAgg(column="B", aggfunc="min"),
#    c_sum=pd.NamedAgg(column="C", aggfunc="sum"))

n_u = master.groupby('NEIGHBORHOOD').agg(
    affordable = pd.NamedAgg(column='Is_Affordable_Master', aggfunc = "sum")
).reset_index()

# %%
voter_and_aff = n_u.set_index('NEIGHBORHOOD').join(neighborhood.set_index('nbhd')).reset_index()

# %%
voter_and_aff
# Out:
#           NEIGHBORHOOD  affordable P0020001 P0020005 P0020006 P0020002  \
# 0              Allston         195    28621    14634     1451     3657
# 1             Back Bay         211    19588    14056      718     1326
# 2          Beacon Hill         204     9336     7521      252      537
# 3             Brighton          35    48330    30596     2289     4978
# 4            Brookline           0      NaN      NaN      NaN      NaN
# 5          Charlestown           3    19120    13626      990     2075
# 6            Chinatown         193     7143     1898      297      477
# 7           Dorchester          14   122191    27411    42714    25285
# 8             Downtown           0    13451     9174      537      961
# 9          East Boston          17    43066    15760     1403    21700
# 10              Fenway         178    37733    20456     2396     3643
# 11  Financial District           1      NaN      NaN      NaN      NaN
# 12           Hyde Park           2    33009     7449    15171     7901
# 13       Jamaica Plain         169    41012    22032     4686     8921
# 14             Kenmore         244      NaN      NaN      NaN      NaN
# 15             Markets           0      NaN      NaN      NaN      NaN
# 16            Mattapan           3    23834     1489    16277     4079
# 17           North End          91    10805     9306      141      528
# 18          Prudential          17      NaN      NaN      NaN      NaN
# 19           Readville           0      NaN      NaN      NaN      NaN
# 20          Roslindale           9    29386    13428     6045     7373
# 21             Roxbury           6    54905     7182    22796    16728
# 22    Roxbury Crossing           0      NaN      NaN      NaN      NaN
# 23        South Boston          72    37917    29139     1529     3887
# 24           South End         789    29373    16618     2959     3783
# 25            West End         123     7705     4933      338      613
# 26        West Roxbury           3    31561    20918     3312     3567
# 27           not found           0      NaN      NaN      NaN      NaN
#
#    P002aapi P002others P0040001 P0040005  ... P0050005 P0050006 P0050007  \
# 0      7173       1706    26668    14022  ...       26        0     3364
# 1      2604        884    18374    13296  ...      269        0     1701
# 2       630        396     8603     6980  ...        0        0       33
# 3      7801       2666    44129    28706  ...      240       56     3713
# 4       NaN        NaN      NaN      NaN  ...      NaN      NaN      NaN
# 5      1650        779    15661    11689  ...       55        0       55
# 6      4281        190     6343     1790  ...      224        0      457
# 7     13360      13421    95365    24327  ...      291        0      936
# 8      2286        493    12675     8764  ...       97        0     4116
# 9      1932       2271    34826    14039  ...      132        0      109
# 10     9218       2020    36715    20099  ...      261        0    16406
# 11      NaN        NaN      NaN      NaN  ...      NaN      NaN      NaN
# 12      677       1811    26470     6494  ...       67        0      134
# 13     2985       2388    34817    19642  ...      319      120      529
# 14      NaN        NaN      NaN      NaN  ...      NaN      NaN      NaN
# 15      NaN        NaN      NaN      NaN  ...      NaN      NaN      NaN
# 16      490       1499    18511     1332  ...       85        0      102
# 17      445        385    10236     8888  ...       41        0      148
# 18      NaN        NaN      NaN      NaN  ...      NaN      NaN      NaN
# 19      NaN        NaN      NaN      NaN  ...      NaN      NaN      NaN
# 20     1018       1522    23604    11486  ...      438        0       57
# 21     3277       4922    43502     6661  ...        0       41     3622
# 22      NaN        NaN      NaN      NaN  ...      NaN      NaN      NaN
# 23     2077       1285    33614    26930  ...      188        0      125
# 24     4677       1336    25922    15203  ...        0       45      661
# 25     1440        381     7098     4620  ...        0       57       53
# 26     2451       1313    25457    17676  ...      412        0       93
# 27      NaN        NaN      NaN      NaN  ...      NaN      NaN      NaN
#
#    P0050008 P0050009 P0050010 H0010001 H0010002 H0010003       hhsize
# 0      3214        0      150    12527    11740      787  2.149148211
# 1      1578        0      123    12373    10788     1585  1.633110864
# 2         0        0       33     6037     5485      552  1.696080219
# 3      3493        0      220    21874    20822     1052    2.1279416
# 4       NaN      NaN      NaN      NaN      NaN      NaN          NaN
# 5         0       30       25     9525     8932      593  2.128302732
# 6       443        0       14     3644     3299      345  1.958775386
# 7         0        0      936    47965    44823     3142  2.692323138
# 8      3283        0      833     6654     5401     1253  1.710423996
# 9         0        0      109    18016    16695     1321  2.564420485
# 10    16197        0      209    13968    12661     1307  1.659663534
# 11      NaN      NaN      NaN      NaN      NaN      NaN          NaN
# 12       64        0       70    12613    12066      547  2.719045251
# 13      160        0      369    18891    17724     1167   2.25423155
# 14      NaN      NaN      NaN      NaN      NaN      NaN          NaN
# 15      NaN      NaN      NaN      NaN      NaN      NaN          NaN
# 16        0        0      102     9346     8821      525   2.66250992
# 17        0      116       32     6832     6314      518  1.681343047
# 18      NaN      NaN      NaN      NaN      NaN      NaN          NaN
# 19      NaN      NaN      NaN      NaN      NaN      NaN          NaN
# 20        0        0       57    12114    11534      580  2.504074909
# 21     2520        0     1102    22034    20345     1689  2.474318014
# 22      NaN      NaN      NaN      NaN      NaN      NaN          NaN
# 23        0        0      125    19140    17961     1179  2.090529481
# 24        0        0      661    16619    15253     1366  1.879433554
# 25        0        0       53     5243     4572      671   1.65376203
# 26        0        0       93    14070    13390      680  2.319342793
# 27      NaN      NaN      NaN      NaN      NaN      NaN          NaN
#
# [28 rows x 35 columns]

# %%
import matplotlib.pyplot as plt

# %%
voter_and_aff['P0020005'].fillna('0').astype(int)
# Out:
# 0     14634
# 1     14056
# 2      7521
# 3     30596
# 4         0
# 5     13626
# 6      1898
# 7     27411
# 8      9174
# 9     15760
# 10    20456
# 11        0
# 12     7449
# 13    22032
# 14        0
# 15        0
# 16     1489
# 17     9306
# 18        0
# 19        0
# 20    13428
# 21     7182
# 22        0
# 23    29139
# 24    16618
# 25     4933
# 26    20918
# 27        0
# Name: P0020005, dtype: int64

# %%
plt.scatter(voter_and_aff['affordable'],voter_and_aff['P0020005'].fillna('0').astype(int))  ##white only

# %%
plt.scatter(voter_and_aff['affordable'],voter_and_aff['P0040006'].fillna('0').astype(int)) ##black only

# %%
#P0020002
plt.scatter(voter_and_aff['affordable'],voter_and_aff['P0020002'].fillna('0').astype(int)) ##hispanic

# %%
black_to_white = voter_and_aff['P0040006'].fillna('0').astype(int)/voter_and_aff['P0040005'].fillna('0').astype(int)

# %%
import numpy as np
a, b = np.polyfit(black_to_white.fillna(0),voter_and_aff['affordable'], 1)
plt.xlim([-0.1, 0.5])
plt.ylim([-0.2, 300])
plt.scatter(black_to_white.fillna(0),voter_and_aff['affordable'])
plt.plot(black_to_white.fillna(0), a*black_to_white.fillna(0)+b, color='red')

# %%
#H0010003 Vacancies and black population
plt.scatter(voter_and_aff['H0010003'].fillna('0').astype(int),black_to_white.fillna(0))
plt.xlim([-0.1, 1500])
plt.ylim([-0.2, 2])
# Out:
# (-0.2, 2.0)
