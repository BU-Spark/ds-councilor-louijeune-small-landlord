# %%
import pandas as pd

# %%
master = pd.read_csv('master_with_neighborhood_for_census.csv')

# %%
master['RES_UNITS'].value_counts()
# Out:
# 0      101726
# 1       66382
# 3        3812
# 2        2650
# 4        1029
#         ...
# 57          1
# 113         1
# 716         1
# 116         1
# 188         1
# Name: RES_UNITS, Length: 149, dtype: int64

# %%
master['RES_FLOOR'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
include_list = [i[0] for i in list(zip(master['BLDG_TYPE'].value_counts().keys(),master['BLDG_TYPE'].value_counts())) if i[1] > 10_000]

# %%
master['BLDG_TYPE_INPUT'] = master.apply(lambda x : x['BLDG_TYPE'] if x['BLDG_TYPE'] in include_list else 'Other_type',axis = 1)

# %%
include_list
# Out:
# ['RM - Row Middle',
#  'CL - Colonial',
#  'LR - Low Rise',
#  'DK - Decker',
#  'MR - Mid Rise',
#  'CV - Conventional',
#  'FS - Free Standing',
#  'NoBld - ']

# %%
def limit_for_prediction(df, input_column_name, output_column_name, cut_off,other):
    include_list = [i[0] for i in list(zip(df[input_column_name].value_counts().keys(),df[input_column_name].value_counts())) if i[1] > cut_off]
    df[output_column_name] = master.apply(lambda x : x[input_column_name] if x[input_column_name] in include_list else other,axis = 1)

# %%
limit_for_prediction(master, "RES_FLOOR", "RES_FLOOR_INPUT", 10_000,other = 'Other')
limit_for_prediction(master, "RES_UNITS", "RES_UNITS_INPUT", 500,other = 'Other')

# %%
master.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'PID', 'CM_ID', 'GIS_ID', 'ST_NUM',
#        'ST_NAME', 'UNIT_NUM', 'CITY', 'ZIPCODE', 'BLDG_SEQ', 'NUM_BLDGS',
#        'LUC', 'LU', 'LU_DESC', 'BLDG_TYPE', 'OWN_OCC', 'OWNER',
#        'MAIL_ADDRESSEE', 'MAIL_ADDRESS', 'MAIL_CITY', 'MAIL_STATE',
#        'MAIL_ZIPCODE', 'RES_FLOOR', 'CD_FLOOR', 'RES_UNITS', 'COM_UNITS',
#        'RC_UNITS', 'LAND_SF', 'GROSS_AREA', 'LIVING_AREA', 'LAND_VALUE',
#        'BLDG_VALUE', 'TOTAL_VALUE', 'GROSS_TAX', 'YR_BUILT', 'YR_REMODEL',
#        'STRUCTURE_CLASS', 'ROOF_STRUCTURE', 'ROOF_COVER', 'INT_WALL',
#        'EXT_FINISHED', 'INT_COND', 'EXT_COND', 'OVERALL_COND', 'BED_RMS',
#        'FULL_BTH', 'HLF_BTH', 'KITCHEN', 'TT_RMS', 'BDRM_COND', 'BTHRM_STYLE1',
#        'BTHRM_STYLE2', 'BTHRM_STYLE3', 'KITCHEN_TYPE', 'KITCHEN_STYLE1',
#        'KITCHEN_STYLE2', 'KITCHEN_STYLE3', 'HEAT_TYPE', 'HEAT_FUEL', 'AC_TYPE',
#        'FIRE_PLACE', 'ORIENTATION', 'NUM_PARKING', 'PROP_VIEW', 'CORNER_UNIT',
# ...

# %%
bins = [0, 1900, 1925, 1950, 1975, 2025]
master['YR_BUILT_INPUT'] = pd.cut(master['YR_BUILT'], bins).astype(str)

# %%
master['YR_BUILT_INPUT']
# Out:
# 0            (0, 1900]
# 1         (1900, 1925]
# 2         (1900, 1925]
# 3            (0, 1900]
# 4            (0, 1900]
#               ...
# 178593             nan
# 178594             nan
# 178595    (1900, 1925]
# 178596    (1925, 1950]
# 178597       (0, 1900]
# Name: YR_BUILT_INPUT, Length: 178598, dtype: object

# %%
train_data_all = master[['Is_Affordable_Master'
                         ,'RES_UNITS_INPUT'
                         ,'YR_BUILT_INPUT'
                         ,'BLDG_TYPE_INPUT'  ##made it singular :(
                         ,'OWN_OCC'
                         #,'LAND_VALUE'  scant data
                         #,'LIVING_AREA'
                         ,'BLDG_VALUE']]

# %%
train_data_all['BLDG_VALUE'] = train_data_all.apply(lambda x : str(x['BLDG_VALUE']).replace(',',''),axis = 1)
train_data_all['BLDG_VALUE'] = train_data_all['BLDG_VALUE'].astype(float)
train_data_all['BLDG_VALUE'] = train_data_all['BLDG_VALUE'].replace(to_replace=0.0, value=train_data_all['BLDG_VALUE'].mean())
train_data_all['BLDG_VALUE'] = (train_data_all['BLDG_VALUE'] - train_data_all['BLDG_VALUE'].mean())/train_data_all['BLDG_VALUE'].std()
#train_data_all['LAND_VALUE'] = train_data_all.apply(lambda x : str(x['LAND_VALUE']).replace(',',''),axis = 1)
#train_data_all['LAND_VALUE'] = train_data_all['LAND_VALUE'].astype(float)
train_data_all['OWN_OCC'].replace(('Y', 'N'), (1, 0), inplace=True)
train_data_all = train_data_all.dropna(axis = 0, how='any')
# Out:
# /var/folders/hq/zz_5zb251633yqqbh6076p782zzx8q/T/ipykernel_32213/2260105643.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data_all['BLDG_VALUE'] = train_data_all.apply(lambda x : str(x['BLDG_VALUE']).replace(',',''),axis = 1)
# /var/folders/hq/zz_5zb251633yqqbh6076p782zzx8q/T/ipykernel_32213/2260105643.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data_all['BLDG_VALUE'] = train_data_all['BLDG_VALUE'].astype(float)
# ...

# %%
train_data_all['Is_Affordable_Master'] = train_data_all['Is_Affordable_Master'].astype(int)
# Out:
# /var/folders/hq/zz_5zb251633yqqbh6076p782zzx8q/T/ipykernel_32213/2196754806.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data_all['Is_Affordable_Master'] = train_data_all['Is_Affordable_Master'].astype(int)

# %%
def sampler(all_data, lines_all_train = 5000):
    aff = all_data.loc[all_data['Is_Affordable_Master'] == 1]
    other = all_data.loc[all_data['Is_Affordable_Master'] == 0]
    addin = other.sample(lines_all_train)
    return pd.concat([aff, addin], ignore_index=True, axis=0)

train_data = sampler(train_data_all,5000)  #this uses all the affordable units, and 5000 of the others.

# %%
train_data
# Out:
#       Is_Affordable_Master RES_UNITS_INPUT YR_BUILT_INPUT BLDG_TYPE_INPUT  \
# 0                        1               0   (1900, 1925]      Other_type
# 1                        1               0      (0, 1900]      Other_type
# 2                        1           Other   (1975, 2025]   LR - Low Rise
# 3                        1               1   (1975, 2025]   LR - Low Rise
# 4                        1               1   (1975, 2025]   LR - Low Rise
# ...                    ...             ...            ...             ...
# 7574                     0               0   (1900, 1925]      Other_type
# 7575                     0               0      (0, 1900]      Other_type
# 7576                     0               1   (1975, 2025]      Other_type
# 7577                     0               3   (1900, 1925]     DK - Decker
# 7578                     0               1   (1975, 2025]      Other_type
#
#       OWN_OCC  BLDG_VALUE
# 0           0   -0.060932
# ...

# %%
train_data.sample(50)
# Out:
#       Is_Affordable_Master RES_UNITS_INPUT YR_BUILT_INPUT     BLDG_TYPE_INPUT  \
# 3446                     0               0      (0, 1900]     RM - Row Middle
# 1460                     1               1   (1975, 2025]          Other_type
# 1745                     1               1   (1975, 2025]          Other_type
# 180                      1               0            nan            NoBld -
# 109                      1               1      (0, 1900]          Other_type
# 3032                     0               1   (1900, 1925]     RM - Row Middle
# 2595                     0               1   (1900, 1925]       LR - Low Rise
# 5677                     0               0   (1950, 1975]       CL - Colonial
# 2549                     1               1   (1975, 2025]       LR - Low Rise
# 4418                     0               0            nan          Other_type
# 5067                     0               1   (1925, 1950]  FS - Free Standing
# ...

# %%
import statsmodels.formula.api as smf
import pandas as pd


all_columns = ' + '.join(train_data.columns[1:])
formula = "Is_Affordable_Master ~ BLDG_VALUE + OWN_OCC + C(RES_UNITS_INPUT)  + C(BLDG_TYPE_INPUT)" ##year and type made it singular :(
print(formula)
# Build the model
log_reg_1 = smf.logit(formula, data=train_data).fit()
## Optimization terminated successfully.
##          Current function value: 0.131593
##          Iterations 11
# Out:
# Is_Affordable_Master ~ BLDG_VALUE + OWN_OCC + C(RES_UNITS_INPUT)  + C(BLDG_TYPE_INPUT)
# ...
#          Current function value: 0.413872
#          Iterations: 35
# /Users/dallin.gordon/opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
print(log_reg_1.summary())
# Out:
#                             Logit Regression Results
# ...
# Dep. Variable:     Is_Affordable_Master   No. Observations:                 7579
# Model:                            Logit   Df Residuals:                     7561
# Method:                             MLE   Df Model:                           17
# Date:                  Sat, 03 Dec 2022   Pseudo R-squ.:                  0.3546
# Time:                          23:32:22   Log-Likelihood:                -3136.7
# converged:                        False   LL-Null:                       -4859.8
# Covariance Type:              nonrobust   LLR p-value:                     0.000
# ...
#                                                coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                   -5.0067      0.582     -8.597      0.000      -6.148      -3.865
# ...

# %%
train_data_all
# Out:
#         Is_Affordable_Master RES_UNITS_INPUT YR_BUILT_INPUT  \
# 0                          0               0      (0, 1900]
# 1                          0               0   (1900, 1925]
# 2                          0               0   (1900, 1925]
# 3                          0               0      (0, 1900]
# 4                          0               0      (0, 1900]
# ...                      ...             ...            ...
# 178593                     0               0            nan
# 178594                     0               0            nan
# 178595                     0               0   (1900, 1925]
# 178596                     0               0   (1925, 1950]
# 178597                     0               0      (0, 1900]
#
#           BLDG_TYPE_INPUT  OWN_OCC  BLDG_VALUE  reg1_5000  reg2_5000  \
# 0              Other_type        1   -0.062480   0.156853   0.171167
# 1         RM - Row Middle        1   -0.059991   0.003053   0.003732
# ...

# %%
#train_data_all['reg3_5000'] = log_reg_1.predict(train_data_all)

# %%
train_data_all['reg_avg'] = train_data_all[['reg1_5000','reg2_5000','reg3_5000']].sum(axis = 1)/3

# %%
res = master.join(train_data_all['reg_avg'], lsuffix='', rsuffix='_Prediction')

# %%
master
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 master
#
# NameError: name 'master' is not defined

# %%
res.to_csv('master_with_regression_output.csv')

# %%
res.loc[res['Is_Affordable_Master']]
# Out:
#         Unnamed: 0.1  Unnamed: 0         PID       CM_ID        GIS_ID ST_NUM  \
# 1912            1912        1912   101647000              1.016470e+08  971
# 4160            4160        4160   103614000              1.036140e+08  408
# 7060            7060        7060   105392000  0105392000  1.053920e+08   10
# 7061            7061        7061   105392002  0105392000  1.053920e+08   10
# 7062            7062        7062   105392004  0105392000  1.053920e+08   10
# ...              ...         ...         ...         ...           ...    ...
# 173142        173142      173142  2202177054  2202177000  2.202177e+09  214
# 173143        173143      173143  2202177056  2202177000  2.202177e+09  214
# 173144        173144      173144  2202177058  2202177000  2.202177e+09  214
# 173145        173145      173145  2202177060  2202177000  2.202177e+09  214
# 173618        173618      173618  2202435001              2.202435e+09  375
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
counts, bins = np.histogram(res['reg_avg'].loc[res['Is_Affordable_Master']], bins=20)
plt.stairs(counts, bins)  ##this is the predictions for the affordable units

# %%
counts, bins = np.histogram(res['reg_avg'].loc[~res['Is_Affordable_Master']], bins=20, range = (0,1))
plt.stairs(counts, bins)  ###EXCELLENT. suggests some positives, but MOST ARE NEGATIVE!!!!!

# %%
final_s = res['ZIPCODE'].loc[res['reg_avg'] > 0.5].value_counts()

# %%
final_s.sort_index().plot(kind='bar') ##sorted by area code!!!!!!!!
# Out:
# <AxesSubplot:>

# %%
d = pd.read_csv('master_with_regression_output.csv')

# %%
d['pred_aff'] = d['reg_avg'] > 0.5

# %%
d[['OWN_OCC','pred_aff']].loc[d['NEIGHBORHOOD'] == 'Mattapan'].value_counts() #Mattapan
# Out:
# OWN_OCC  pred_aff
# Y        False       2636
# N        False       2027
#          True          93
# Y        True          73
# dtype: int64

# %%
d['NEIGHBORHOOD'].value_counts()
# Out:
# Dorchester            24929
# South Boston          17266
# Jamaica Plain         11964
# Brighton              11768
# West Roxbury          10960
# Roxbury               10282
# Back Bay               9449
# East Boston            9315
# Hyde Park              9192
# Roslindale             9130
# South End              8937
# Charlestown            7192
# West End               5299
# Fenway                 5246
# Mattapan               4829
# Allston                4442
# Kenmore                3741
# Chinatown              2891
# Financial District     2458
# North End              2349
# Beacon Hill            2157
# Roxbury Crossing       1865
# Markets                1847
# not found              1025
# Prudential               36
# Brookline                24
# Downtown                  4
# Readville                 1
# Name: NEIGHBORHOOD, dtype: int64
