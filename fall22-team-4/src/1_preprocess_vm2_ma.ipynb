# %%
import pandas as pd

# %%
wanted_cols = """
Residence_Addresses_AddressLine
Residence_Addresses_City
Residence_Addresses_State
Residence_Addresses_StreetName
Residence_HHGender_Description
Residence_HHParties_Description
Voters_FirstName
Voters_MiddleName
Voters_LastName
Voters_NameSuffix
Parties_Description
Ethnic_Description
EthnicGroups_EthnicGroup1Desc
CommercialData_EstHomeValue
CommercialData_EstimatedHHIncomeAmount
""".split()

# %%
df = pd.read_csv('../data/raw/VM2--MA--2021-10-11/VM2--MA--2021-10-11-DEMOGRAPHIC.tab', sep='\t', encoding = "ISO-8859-1", usecols=wanted_cols)
df
# Out:
#         Voters_FirstName Voters_MiddleName  Voters_LastName Voters_NameSuffix  \
# 0               Lilavois               NaN          Frantzo               NaN
# 1                Marsden            Carter          Hedrick                II
# 2                  Katie              Lynn           Maloon               NaN
# 3                 Eileen                 S             Penn               NaN
# 4                   Lita                 B         Isabelle               NaN
# ...                  ...               ...              ...               ...
# 4506884           Gladys               NaN    Rivera Rivera               NaN
# 4506885            Angel             Ramon  Gonzalez Guzman               NaN
# 4506886            Deena                 M     Particianone               NaN
# 4506887         Natanael               NaN       De La Rosa               NaN
# 4506888          Rochely            Carmen     Castro Ozuna               NaN
#
# ...

# %%
df = df[wanted_cols]
df.to_csv('../data/clean/voter_ma_info.csv', index=False)
