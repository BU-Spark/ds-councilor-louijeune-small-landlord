# %%
import os

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import googlemaps
from datetime import datetime
from dotenv import load_dotenv

# %% [markdown]
# ## Load Data

# %%
afford_housing = pd.read_csv('./data/affordable-housing-addresses.csv')
all_housing = pd.read_csv('./data/property-data.csv')

# %%
afford_housing.head()
# Out:
#                 Project Name Neighborhood  Zip Code  TtlProjUnits  RentUnits  \
# 0  Abbot Street/ Shawmut Ave      Roxbury      2119            16         16
# 1            Academy Homes I      Roxbury      2119           202        202
# 2           Academy Homes II      Roxbury      2119           236        236
# 3        Adams Court Phase A     Mattapan      2126            50         50
# 4        Adams Court Phase B     Mattapan      2126            45         45
#
#    OwnUnits  TtlMarket  MarketRent  MarketOwn  Total Income-Restricted  \
# 0         0        0.0         0.0        0.0                       16
# 1         0       52.0        52.0        0.0                      150
# 2         0        0.0         0.0        0.0                      236
# 3         0        0.0         0.0        0.0                       50
# 4         0        0.0         0.0        0.0                       45
#
#    Income-Restricted Rental  Income-Restricted Ownership  Tenure  \
# 0                        16                          0.0  Rental
# 1                       150                          0.0  Rental
# 2                       236                          0.0  Rental
# 3                        50                          0.0  Rental
# 4                        45                          0.0  Rental
#
#   Public/ Private Includes Senior Units? Section 8  \
# 0         Private                    NaN       NaN
# 1         Private                    NaN       NaN
# 2         Private                    NaN         Y
# 3         Private                    NaN       NaN
# 4         Private                    NaN       NaN
#
#                                    formatted_address
# 0   100 Shawmut Ave, Boston, MA 02118, United States
# 1  1592 Columbus Ave, Roxbury, MA 02119, United S...
# 2  2926 Washington St, Roxbury, MA 02119, United ...
# 3  59 Msgr Patrick J Lydon Way, Boston, MA 02124,...
# 4                                                NaN

# %%
all_housing.head()
# Out:
#          PID CM_ID       GIS_ID      ST_NUM       ST_NAME UNIT_NUM  \
# 0  100001000        100001000.0  104 A 104      PUTNAM ST      NaN
# 1  100002000        100002000.0       197    LEXINGTON ST      NaN
# 2  100003000        100003000.0       199    LEXINGTON ST      NaN
# 3  100004000        100004000.0       201    LEXINGTON ST      NaN
# 4  100005000        100005000.0       203    LEXINGTON ST      NaN
#
#           CITY  ZIPCODE  BLDG_SEQ  NUM_BLDGS  ...   KITCHEN_STYLE2  \
# 0  EAST BOSTON     2128       1.0          1  ...  S - Semi-Modern
# 1  EAST BOSTON     2128       1.0          1  ...       M - Modern
# 2  EAST BOSTON     2128       1.0          1  ...  S - Semi-Modern
# 3  EAST BOSTON     2128       1.0          1  ...  S - Semi-Modern
# 4  EAST BOSTON     2128       1.0          1  ...  S - Semi-Modern
#
#     KITCHEN_STYLE3           HEAT_TYPE HEAT_FUEL         AC_TYPE FIRE_PLACE  \
# 0  S - Semi-Modern  W - Ht Water/Steam       NaN        N - None          0
# 1       M - Modern  F - Forced Hot Air       NaN  C - Central AC          0
# 2  S - Semi-Modern      S - Space Heat       NaN        N - None          0
# 3  S - Semi-Modern  W - Ht Water/Steam       NaN        N - None          0
# 4              NaN  W - Ht Water/Steam       NaN        N - None          0
#
#   ORIENTATION NUM_PARKING    PROP_VIEW CORNER_UNIT
# 0         NaN           3  A - Average         NaN
# 1         NaN           0  A - Average         NaN
# 2         NaN           0  A - Average         NaN
# 3         NaN           0  A - Average         NaN
# 4         NaN           0  A - Average         NaN
#
# [5 rows x 64 columns]

# %% [markdown]
# ## Cleaning street addresses

# %%
# isolating affordable housing street addresses
import re

split_add = afford_housing["formatted_address"].str.split("[,]", expand = True).astype(str).applymap(lambda x: x.strip())

#checks for first row value that starts with a number
def helper(x):
    for i in x:
        if bool(re.search('^[0-9].*',  i)):
            return i
        else:
            return np.nan

afford_housing["street_address"] = split_add.apply(lambda x: helper(x), axis = 1)
afford_housing.drop(["formatted_address"], axis = 1, inplace = True)
afford_housing.head()
# Out:
#                 Project Name Neighborhood  Zip Code  TtlProjUnits  RentUnits  \
# 0  Abbot Street/ Shawmut Ave      Roxbury      2119            16         16
# 1            Academy Homes I      Roxbury      2119           202        202
# 2           Academy Homes II      Roxbury      2119           236        236
# 3        Adams Court Phase A     Mattapan      2126            50         50
# 4        Adams Court Phase B     Mattapan      2126            45         45
#
#    OwnUnits  TtlMarket  MarketRent  MarketOwn  Total Income-Restricted  \
# 0         0        0.0         0.0        0.0                       16
# 1         0       52.0        52.0        0.0                      150
# 2         0        0.0         0.0        0.0                      236
# 3         0        0.0         0.0        0.0                       50
# 4         0        0.0         0.0        0.0                       45
#
#    Income-Restricted Rental  Income-Restricted Ownership  Tenure  \
# 0                        16                          0.0  Rental
# 1                       150                          0.0  Rental
# 2                       236                          0.0  Rental
# 3                        50                          0.0  Rental
# 4                        45                          0.0  Rental
#
#   Public/ Private Includes Senior Units? Section 8  \
# 0         Private                    NaN       NaN
# 1         Private                    NaN       NaN
# 2         Private                    NaN         Y
# 3         Private                    NaN       NaN
# 4         Private                    NaN       NaN
#
#                 street_address
# 0              100 Shawmut Ave
# 1            1592 Columbus Ave
# 2           2926 Washington St
# 3  59 Msgr Patrick J Lydon Way
# 4                          NaN

# %%
all_housing["street_address"] = all_housing.apply(lambda x: x["ST_NUM"].title() + ' ' + x["ST_NAME"].title(), axis = 1)
all_housing.drop(["ST_NUM", "ST_NAME"], axis = 1, inplace = True)
all_housing.head()
# Out:
#          PID CM_ID       GIS_ID UNIT_NUM         CITY  ZIPCODE  BLDG_SEQ  \
# 0  100001000        100001000.0      NaN  EAST BOSTON     2128       1.0
# 1  100002000        100002000.0      NaN  EAST BOSTON     2128       1.0
# 2  100003000        100003000.0      NaN  EAST BOSTON     2128       1.0
# 3  100004000        100004000.0      NaN  EAST BOSTON     2128       1.0
# 4  100005000        100005000.0      NaN  EAST BOSTON     2128       1.0
#
#    NUM_BLDGS  LUC  LU  ...   KITCHEN_STYLE3           HEAT_TYPE HEAT_FUEL  \
# 0          1  105  R3  ...  S - Semi-Modern  W - Ht Water/Steam       NaN
# 1          1  105  R3  ...       M - Modern  F - Forced Hot Air       NaN
# 2          1  105  R3  ...  S - Semi-Modern      S - Space Heat       NaN
# 3          1  105  R3  ...  S - Semi-Modern  W - Ht Water/Steam       NaN
# 4          1  104  R2  ...              NaN  W - Ht Water/Steam       NaN
#
#           AC_TYPE FIRE_PLACE ORIENTATION NUM_PARKING    PROP_VIEW CORNER_UNIT  \
# 0        N - None          0         NaN           3  A - Average         NaN
# 1  C - Central AC          0         NaN           0  A - Average         NaN
# 2        N - None          0         NaN           0  A - Average         NaN
# 3        N - None          0         NaN           0  A - Average         NaN
# 4        N - None          0         NaN           0  A - Average         NaN
#
#          street_address
# 0  104 A 104  Putnam St
# 1    197   Lexington St
# 2    199   Lexington St
# 3    201   Lexington St
# 4    203   Lexington St
#
# [5 rows x 63 columns]

# %% [markdown]
# ## Remove non-rental unites (still needs work)

# %%
afford_rentals = afford_housing.loc[afford_housing["Tenure"].str.match(".*Rental.*")]

# %%
# keeping columns useful for cleaning up non-rental properties
cols = ["ST_NUM", "ST_NAME", "CITY", "ZIPCODE", "NUM_BLDGS", "LU", "OWN_OCC", "RES_UNITS", "RC_UNITS"]
all_rentals = all_housing[cols]

# remove any properties that don't have residential units
all_rentals = all_rentals.loc[all_rentals["RES_UNITS"] > 0]

# remove any buildings that only have one residential unit that is occupied by the property owner
all_rentals = all_rentals.loc[~((all_rentals["OWN_OCC"] == "Y") & (all_rentals["RES_UNITS"] == 1))]
all_rentals.head()
# Out:
#    ST_NUM       ST_NAME         CITY  ZIPCODE  NUM_BLDGS  LU OWN_OCC  \
# 17  239    LEXINGTON ST  EAST BOSTON     2128          1  CM       N
# 22  241    LEXINGTON ST  EAST BOSTON     2128          1  CM       N
# 23  241    LEXINGTON ST  EAST BOSTON     2128          1  CD       N
# 25  241    LEXINGTON ST  EAST BOSTON     2128          1  CD       N
# 30  249    LEXINGTON ST  EAST BOSTON     2128          1  CM       N
#
#     RES_UNITS  RC_UNITS
# 17          4         0
# 22          3         0
# 23          1         0
# 25          1         0
# 30          3         0

# %%
all_housing.loc[all_housing["LU"] == "R3"]["RES_UNITS"].value_counts()
# Out:
# 0    13744
# 3       17
# Name: RES_UNITS, dtype: int64
