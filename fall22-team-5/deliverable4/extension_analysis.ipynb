# %% [markdown]
# # Data Analysis for Extension Project

# %%
import pandas 
# read first 10 lines in tsv file
df = pandas.read_csv('data/voter_file_vote_history.tsv', sep='\t', nrows=10)

df.head(1)
# Out:
#        LALVOTERID  Local_or_Municipal_2021_09_14  \
# 0  LALMA528324496                            NaN
#
#    Local_or_Municipal_2021_05_11  Local_or_Municipal_2021_05_10  \
# 0                            NaN                            NaN
#
#    Local_or_Municipal_2021_05_08  Local_or_Municipal_2021_05_04  \
# 0                            NaN                            NaN
#
#    Local_or_Municipal_2021_05_03  Local_or_Municipal_2021_05_01  \
# 0                            NaN                            NaN
#
#    Local_or_Municipal_2021_04_28  Local_or_Municipal_2021_04_27  ...  \
# 0                            NaN                            NaN  ...
#
#    BallotReturnDate_General_2018_11_06  BallotReturnDate_Primary_2018_09_04  \
# 0                                  NaN                                  NaN
#
#    BallotReturnDate_General_2016_11_08  BallotReturnDate_Primary_2016_09_08  \
# 0                                  NaN                                  NaN
#
# ...

# %%
# show me rows that don't have NaNs
# Out:
#        LALVOTERID  Local_or_Municipal_2021_09_14  \
# 0  LALMA528324496                            NaN
# 1  LALMA410149388                            NaN
# 2  LALMA161150467                            NaN
# 3  LALMA161562516                            NaN
# 4  LALMA161508686                            NaN
# 5  LALMA162045204                            NaN
# 6  LALMA162279544                            NaN
# 7  LALMA162106964                            NaN
# 8  LALMA162107713                            NaN
# 9  LALMA609585123                            NaN
#
#    Local_or_Municipal_2021_05_11  Local_or_Municipal_2021_05_10  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
# ...
